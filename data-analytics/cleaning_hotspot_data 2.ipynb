# %%
import numpy as np
import pandas as pd
import pyarrow as pa
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NYC_Wi-Fi_Hotspot_Locations.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
df
# Out:
#       OBJECTID  Borough          Type              Provider  \
# 0        10604        4  Limited Free              SPECTRUM
# 1        10555        4  Limited Free              SPECTRUM
# 2        12370        3          Free      Transit Wireless
# 3         9893        3          Free     Downtown Brooklyn
# 4        10169        1          Free      Transit Wireless
# ...        ...      ...           ...                   ...
# 3314     10872        3  Limited Free              SPECTRUM
# 3315     12026        2          Free  LinkNYC - Citybridge
# 3316     12063        3          Free  LinkNYC - Citybridge
# 3317     12066        3          Free  LinkNYC - Citybridge
# 3318     12083        3          Free  LinkNYC - Citybridge
#
#                         Name  \
# 0          Baisley Pond Park
# 1               Kissena Park
# 2               Grand St (L)
# 3                        NaN
# 4     Lexington Av-63 St (F)
# ...                      ...
# 3314            Carroll Park
# 3315            bx-01-138789
# 3316            bk-01-143982
# 3317            bk-17-126527
# 3318            bk-02-108355
#
#                                                Location   Latitude  Longitude  \
# 0                                        Park Perimeter  40.674860 -73.784120
# 1                                        Park Perimeter  40.747560 -73.818150
# 2                                          Grand St (L)  40.711926 -73.940670
# 3                                         125 Court St.  40.689985 -73.991995
# 4                                Lexington Av-63 St (F)  40.764630 -73.966115
# ...                                                 ...        ...        ...
# 3314  Court off Smith St between Carrol St and 1st P...  40.680630 -73.995382
# 3315                                  312 WILLIS AVENUE  40.810896 -73.921434
# 3316                                   32 GRAHAM AVENUE  40.701930 -73.942239
# 3317                               1339 FLATBUSH AVENUE  40.638560 -73.953603
# 3318                                402 Atlantic Avenue  40.686812 -73.984970
#
#                  X              Y  ...  \
# 0     1.044132e+06  185219.892077  ...
# 1     1.034638e+06  211685.217755  ...
# 2     1.000698e+06  198655.908840  ...
# 3     9.864700e+05  190656.680416  ...
# 4     9.936366e+05  217853.888161  ...
# ...            ...            ...  ...
# 3314  9.855309e+05  187248.314202  ...
# 3315  1.005999e+06  234718.294065  ...
# 3316  1.000265e+06  195013.901033  ...
# 3317  9.971268e+05  171924.271359  ...
# 3318  9.884185e+05  189500.763109  ...
#
#                     Neighborhood Tabulation Area (NTA) Council Distrcit  \
# 0                            Springfield Gardens North               28
# 1                                             Flushing               20
# 2                                    East Williamsburg               34
# 3                         Brooklyn Heights-Cobble Hill               33
# 4                        Upper East Side-Carnegie Hill                4
# ...                                                ...              ...
# 3314          Carroll Gardens-Columbia Street-Red Hook               39
# 3315                            Mott Haven-Port Morris                8
# 3316                                 East Williamsburg               34
# 3317                                           Erasmus               45
# 3318  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill               33
#
#      Postcode BoroCD Census Tract BCTCB2010      BIN         BBL DOITT_ID  \
# 0       11434    412          294       294        0           0     1408
# 1       11355    407          845       845        0           0     1359
# 2       11206    301          495       495        0           0     1699
# 3       11201    302            9         9  3388736  3002777501      298
# 4       10065    108          120       120        0           0      599
# ...       ...    ...          ...       ...      ...         ...      ...
# 3314    11231    306           77        77  3007547  3004490015     1338
# 3315    10454    201           39        39  2000335  2022850010     4113
# 3316    11206    301          491       491  3071609  3031200000     3018
# 3317    11226    317          790       790  3120360  3052110060     3021
# 3318    11217    302           41        41  3255607  3001837500     3038
#
#                  Location (Lat, Long)
# 0     (40.6748599999, -73.7841200005)
# 1     (40.7475599996, -73.8181499997)
# 2     (40.7119259997, -73.9406699994)
# 3     (40.6899850001, -73.9919950004)
# 4     (40.7646300002, -73.9661150001)
# ...                               ...
# 3314  (40.6806299998, -73.9953819995)
# 3315  (40.8108964904, -73.9214341701)
# 3316  (40.7019303441, -73.9422392381)
# 3317  (40.6385596088, -73.9536032378)
# 3318  (40.6868115694, -73.9849696135)
#
# [3319 rows x 29 columns]

# %%
df.shape
# Out:
# (3319, 29)

# %%
# check duplicated rows
print('Number of duplicate (excluding original) rows is:', df.duplicated().sum())
print('Number of duplicate rows (including first) in the table is:', df[df.duplicated(keep=False)].shape[0])
# Show duplicate row data that can be dropped
df[df.duplicated(keep=False)]
# Out:
# Number of duplicate (excluding original) rows is: 0
# Number of duplicate rows (including first) in the table is: 0
# Empty DataFrame
# Columns: [OBJECTID, Borough, Type, Provider, Name, Location, Latitude, Longitude, X, Y, Location_T, Remarks, City, SSID, SourceID, Activated, BoroCode, Borough Name, Neighborhood Tabulation Area Code (NTACODE), Neighborhood Tabulation Area (NTA), Council Distrcit, Postcode, BoroCD, Census Tract, BCTCB2010, BIN, BBL, DOITT_ID, Location (Lat, Long)]
# Index: []
#
# [0 rows x 29 columns]

# %%
df = df[['Name', 'Borough Name', 'Type', 'Longitude', 'Latitude']]

# %%
df
# Out:
#                         Name Borough Name          Type  Longitude   Latitude
# 0          Baisley Pond Park       Queens  Limited Free -73.784120  40.674860
# 1               Kissena Park       Queens  Limited Free -73.818150  40.747560
# 2               Grand St (L)     Brooklyn          Free -73.940670  40.711926
# 3                        NaN     Brooklyn          Free -73.991995  40.689985
# 4     Lexington Av-63 St (F)    Manhattan          Free -73.966115  40.764630
# ...                      ...          ...           ...        ...        ...
# 3314            Carroll Park     Brooklyn  Limited Free -73.995382  40.680630
# 3315            bx-01-138789        Bronx          Free -73.921434  40.810896
# 3316            bk-01-143982     Brooklyn          Free -73.942239  40.701930
# 3317            bk-17-126527     Brooklyn          Free -73.953603  40.638560
# 3318            bk-02-108355     Brooklyn          Free -73.984970  40.686812
#
# [3319 rows x 5 columns]

# %%
without_long_lat = df[df['Longitude'].isnull() | df['Latitude'].isnull()]

without_long_lat
# Out:
# Empty DataFrame
# Columns: [Name, Borough Name, Type, Longitude, Latitude]
# Index: []

# %%
# check the data type
df.dtypes
# Out:
# Name             object
# Borough Name     object
# Type             object
# Longitude       float64
# Latitude        float64
# dtype: object

# %%
# check null value
df.isnull().sum()
# Out:
# Name            230
# Borough Name      0
# Type              0
# Longitude         0
# Latitude          0
# dtype: int64

# %%
df[df['Name'].isnull()]
# Out:
#      Name Borough Name  Type  Longitude   Latitude
# 3     NaN     Brooklyn  Free -73.991995  40.689985
# 6     NaN    Manhattan  Free -73.941693  40.812944
# 12    NaN    Manhattan  Free -73.939510  40.810260
# 52    NaN     Brooklyn  Free -73.989635  40.690883
# 53    NaN     Brooklyn  Free -73.983025  40.692723
# ...   ...          ...   ...        ...        ...
# 3149  NaN     Brooklyn  Free -73.989635  40.690883
# 3160  NaN    Manhattan  Free -74.006637  40.744408
# 3192  NaN    Manhattan  Free -73.941112  40.815114
# 3193  NaN    Manhattan  Free -73.941262  40.813713
# 3256  NaN     Brooklyn  Free -73.990089  40.693069
#
# [230 rows x 5 columns]

# %%
df['Name'] = df['Name'].fillna(df['Borough Name'] + ' wifi')
# Out:
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40796/2264682650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'] = df['Name'].fillna(df['Borough Name'] + ' wifi')

# %%
df
# Out:
#                         Name Borough Name          Type  Longitude   Latitude
# 0          Baisley Pond Park       Queens  Limited Free -73.784120  40.674860
# 1               Kissena Park       Queens  Limited Free -73.818150  40.747560
# 2               Grand St (L)     Brooklyn          Free -73.940670  40.711926
# 3              Brooklyn wifi     Brooklyn          Free -73.991995  40.689985
# 4     Lexington Av-63 St (F)    Manhattan          Free -73.966115  40.764630
# ...                      ...          ...           ...        ...        ...
# 3314            Carroll Park     Brooklyn  Limited Free -73.995382  40.680630
# 3315            bx-01-138789        Bronx          Free -73.921434  40.810896
# 3316            bk-01-143982     Brooklyn          Free -73.942239  40.701930
# 3317            bk-17-126527     Brooklyn          Free -73.953603  40.638560
# 3318            bk-02-108355     Brooklyn          Free -73.984970  40.686812
#
# [3319 rows x 5 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
# change 'Longitude' and 'Latitude' into GeoDataFrame
df['Coordinates'] = list(zip(df.Longitude, df.Latitude))
df['Coordinates'] = df['Coordinates'].apply(Point)

gdf_hotspot = gpd.GeoDataFrame(df, geometry='Coordinates')
# Out:
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40796/1490670134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Coordinates'] = list(zip(df.Longitude, df.Latitude))
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40796/1490670134.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Coordinates'] = df['Coordinates'].apply(Point)

# %%
gdf_hotspot
# Out:
#                         Name Borough Name          Type  Longitude   Latitude  \
# 0          Baisley Pond Park       Queens  Limited Free -73.784120  40.674860
# 1               Kissena Park       Queens  Limited Free -73.818150  40.747560
# 2               Grand St (L)     Brooklyn          Free -73.940670  40.711926
# 3              Brooklyn wifi     Brooklyn          Free -73.991995  40.689985
# 4     Lexington Av-63 St (F)    Manhattan          Free -73.966115  40.764630
# ...                      ...          ...           ...        ...        ...
# 3314            Carroll Park     Brooklyn  Limited Free -73.995382  40.680630
# 3315            bx-01-138789        Bronx          Free -73.921434  40.810896
# 3316            bk-01-143982     Brooklyn          Free -73.942239  40.701930
# 3317            bk-17-126527     Brooklyn          Free -73.953603  40.638560
# 3318            bk-02-108355     Brooklyn          Free -73.984970  40.686812
#
#                      Coordinates
# 0     POINT (-73.78412 40.67486)
# 1     POINT (-73.81815 40.74756)
# 2     POINT (-73.94067 40.71193)
# 3     POINT (-73.99200 40.68999)
# 4     POINT (-73.96612 40.76463)
# ...                          ...
# 3314  POINT (-73.99538 40.68063)
# 3315  POINT (-73.92143 40.81090)
# 3316  POINT (-73.94224 40.70193)
# 3317  POINT (-73.95360 40.63856)
# 3318  POINT (-73.98497 40.68681)
#
# [3319 rows x 6 columns]

# %%
# Read the geojson file
taxi_zone = gpd.read_file('NYC Taxi Zones.geojson')
taxi_zone
# Out:
#              shape_area objectid       shape_leng location_id  \
# 0       0.0007823067885        1   0.116357453189           1
# 1      0.00486634037837        2    0.43346966679           2
# 2     0.000314414156821        3  0.0843411059012           3
# 3     0.000111871946192        4  0.0435665270921           4
# 4     0.000497957489363        5  0.0921464898574           5
# ..                  ...      ...              ...         ...
# 258   0.000168611097013      256  0.0679149669603         256
# 259   0.000394552487366      259   0.126750305191         259
# 260   0.000422345326907      260   0.133514154636         260
# 261  0.0000343423231652      261  0.0271204563616         261
# 262   0.000122330270966      262  0.0490636231541         262
#
#                           zone        borough  \
# 0               Newark Airport            EWR
# 1                  Jamaica Bay         Queens
# 2      Allerton/Pelham Gardens          Bronx
# 3                Alphabet City      Manhattan
# 4                Arden Heights  Staten Island
# ..                         ...            ...
# 258  Williamsburg (South Side)       Brooklyn
# 259         Woodlawn/Wakefield          Bronx
# 260                   Woodside         Queens
# 261         World Trade Center      Manhattan
# 262             Yorkville East      Manhattan
#
#                                               geometry
# 0    MULTIPOLYGON (((-74.18445 40.69500, -74.18449 ...
# 1    MULTIPOLYGON (((-73.82338 40.63899, -73.82277 ...
# 2    MULTIPOLYGON (((-73.84793 40.87134, -73.84725 ...
# 3    MULTIPOLYGON (((-73.97177 40.72582, -73.97179 ...
# 4    MULTIPOLYGON (((-74.17422 40.56257, -74.17349 ...
# ..                                                 ...
# 258  MULTIPOLYGON (((-73.95834 40.71331, -73.95681 ...
# 259  MULTIPOLYGON (((-73.85107 40.91037, -73.85207 ...
# 260  MULTIPOLYGON (((-73.90175 40.76078, -73.90147 ...
# 261  MULTIPOLYGON (((-74.01333 40.70503, -74.01327 ...
# 262  MULTIPOLYGON (((-73.94383 40.78286, -73.94376 ...
#
# [263 rows x 7 columns]

# %%
gdf_taxi_zone = gpd.GeoDataFrame(taxi_zone, geometry='geometry')
gdf_taxi_zone
# Out:
#              shape_area objectid       shape_leng location_id  \
# 0       0.0007823067885        1   0.116357453189           1
# 1      0.00486634037837        2    0.43346966679           2
# 2     0.000314414156821        3  0.0843411059012           3
# 3     0.000111871946192        4  0.0435665270921           4
# 4     0.000497957489363        5  0.0921464898574           5
# ..                  ...      ...              ...         ...
# 258   0.000168611097013      256  0.0679149669603         256
# 259   0.000394552487366      259   0.126750305191         259
# 260   0.000422345326907      260   0.133514154636         260
# 261  0.0000343423231652      261  0.0271204563616         261
# 262   0.000122330270966      262  0.0490636231541         262
#
#                           zone        borough  \
# 0               Newark Airport            EWR
# 1                  Jamaica Bay         Queens
# 2      Allerton/Pelham Gardens          Bronx
# 3                Alphabet City      Manhattan
# 4                Arden Heights  Staten Island
# ..                         ...            ...
# 258  Williamsburg (South Side)       Brooklyn
# 259         Woodlawn/Wakefield          Bronx
# 260                   Woodside         Queens
# 261         World Trade Center      Manhattan
# 262             Yorkville East      Manhattan
#
#                                               geometry
# 0    MULTIPOLYGON (((-74.18445 40.69500, -74.18449 ...
# 1    MULTIPOLYGON (((-73.82338 40.63899, -73.82277 ...
# 2    MULTIPOLYGON (((-73.84793 40.87134, -73.84725 ...
# 3    MULTIPOLYGON (((-73.97177 40.72582, -73.97179 ...
# 4    MULTIPOLYGON (((-74.17422 40.56257, -74.17349 ...
# ..                                                 ...
# 258  MULTIPOLYGON (((-73.95834 40.71331, -73.95681 ...
# 259  MULTIPOLYGON (((-73.85107 40.91037, -73.85207 ...
# 260  MULTIPOLYGON (((-73.90175 40.76078, -73.90147 ...
# 261  MULTIPOLYGON (((-74.01333 40.70503, -74.01327 ...
# 262  MULTIPOLYGON (((-73.94383 40.78286, -73.94376 ...
#
# [263 rows x 7 columns]

# %%
# Ensure both GeoDataFrames are using the same CRS
gdf_hotspot = gdf_hotspot.set_crs("EPSG:4326")
gdf_taxi_zone = gdf_taxi_zone.set_crs("EPSG:4326")

# Perform spatial join with the 'predicate' parameter
result = gpd.sjoin(gdf_hotspot, gdf_taxi_zone, how="inner", predicate='intersects')

# %%
result
# Out:
#                                      Name Borough Name          Type  \
# 0                       Baisley Pond Park       Queens  Limited Free
# 1283                    Baisley Pond Park       Queens  Limited Free
# 2322                    Baisley Pond Park       Queens  Limited Free
# 2894                     Rochdale Village       Queens          Free
# 3071                    Baisley Pond Park       Queens  Limited Free
# ...                                   ...          ...           ...
# 2795                          Parkchester        Bronx          Free
# 2824                               Hollis       Queens          Free
# 2903                              Bayside       Queens          Free
# 2926                              Maspeth       Queens          Free
# 2930  Homecrest - Brooklyn Public Library     Brooklyn          Free
#
#       Longitude   Latitude                 Coordinates  index_right  \
# 0    -73.784120  40.674860  POINT (-73.78412 40.67486)          217
# 1283 -73.786780  40.672680  POINT (-73.78678 40.67268)          217
# 2322 -73.785170  40.673180  POINT (-73.78517 40.67318)          217
# 2894 -73.770590  40.672875  POINT (-73.77059 40.67288)          217
# 3071 -73.782540  40.676090  POINT (-73.78254 40.67609)          217
# ...         ...        ...                         ...          ...
# 2795 -73.858355  40.833736  POINT (-73.85836 40.83374)          181
# 2824 -73.762304  40.720168  POINT (-73.76230 40.72017)          135
# 2903 -73.768362  40.760126  POINT (-73.76836 40.76013)           20
# 2926 -73.893105  40.726995  POINT (-73.89310 40.72700)          157
# 2930 -73.960599  40.595237  POINT (-73.96060 40.59524)          125
#
#               shape_area objectid       shape_leng location_id  \
# 0      0.000281293736407      218  0.0837008281049         218
# 1283   0.000281293736407      218  0.0837008281049         218
# 2322   0.000281293736407      218  0.0837008281049         218
# 2894   0.000281293736407      218  0.0837008281049         218
# 3071   0.000281293736407      218  0.0837008281049         218
# ...                  ...      ...              ...         ...
# 2795  0.0000910644156732      182  0.0393606369479         182
# 2824   0.000423696152789      131   0.116547120922         131
# 2903   0.000871889446182       16   0.141291873771          16
# 2926   0.000354370128323      157   0.131300217777         157
# 2930   0.000296445173366      123  0.0834211389387         123
#
#                            zone   borough
# 0     Springfield Gardens North    Queens
# 1283  Springfield Gardens North    Queens
# 2322  Springfield Gardens North    Queens
# 2894  Springfield Gardens North    Queens
# 3071  Springfield Gardens North    Queens
# ...                         ...       ...
# 2795                Parkchester     Bronx
# 2824            Jamaica Estates    Queens
# 2903                    Bayside    Queens
# 2926                    Maspeth    Queens
# 2930                  Homecrest  Brooklyn
#
# [3318 rows x 13 columns]

# %%
result = result[['Name', 'Longitude', 'Latitude', 'Type', 'zone', "location_id", "borough" ]]
result
# Out:
#                                      Name  Longitude   Latitude          Type  \
# 0                       Baisley Pond Park -73.784120  40.674860  Limited Free
# 1283                    Baisley Pond Park -73.786780  40.672680  Limited Free
# 2322                    Baisley Pond Park -73.785170  40.673180  Limited Free
# 2894                     Rochdale Village -73.770590  40.672875          Free
# 3071                    Baisley Pond Park -73.782540  40.676090  Limited Free
# ...                                   ...        ...        ...           ...
# 2795                          Parkchester -73.858355  40.833736          Free
# 2824                               Hollis -73.762304  40.720168          Free
# 2903                              Bayside -73.768362  40.760126          Free
# 2926                              Maspeth -73.893105  40.726995          Free
# 2930  Homecrest - Brooklyn Public Library -73.960599  40.595237          Free
#
#                            zone location_id   borough
# 0     Springfield Gardens North         218    Queens
# 1283  Springfield Gardens North         218    Queens
# 2322  Springfield Gardens North         218    Queens
# 2894  Springfield Gardens North         218    Queens
# 3071  Springfield Gardens North         218    Queens
# ...                         ...         ...       ...
# 2795                Parkchester         182     Bronx
# 2824            Jamaica Estates         131    Queens
# 2903                    Bayside          16    Queens
# 2926                    Maspeth         157    Queens
# 2930                  Homecrest         123  Brooklyn
#
# [3318 rows x 7 columns]

# %%
# check null value
result.isnull().sum()
# Out:
# Type           0
# Longitude      0
# Latitude       0
# Name           0
# zone           0
# location_id    0
# borough        0
# dtype: int64

# %% [markdown]
# # the code below used for model

# %%
# Rename the column
result.rename(columns={'Type': 'Wifi Type'}, inplace=True)

# %%
result
# Out:
#                                      Name  Longitude   Latitude     Wifi Type  \
# 0                       Baisley Pond Park -73.784120  40.674860  Limited Free
# 1283                    Baisley Pond Park -73.786780  40.672680  Limited Free
# 2322                    Baisley Pond Park -73.785170  40.673180  Limited Free
# 2894                     Rochdale Village -73.770590  40.672875          Free
# 3071                    Baisley Pond Park -73.782540  40.676090  Limited Free
# ...                                   ...        ...        ...           ...
# 2795                          Parkchester -73.858355  40.833736          Free
# 2824                               Hollis -73.762304  40.720168          Free
# 2903                              Bayside -73.768362  40.760126          Free
# 2926                              Maspeth -73.893105  40.726995          Free
# 2930  Homecrest - Brooklyn Public Library -73.960599  40.595237          Free
#
#                            zone location_id   borough
# 0     Springfield Gardens North         218    Queens
# 1283  Springfield Gardens North         218    Queens
# 2322  Springfield Gardens North         218    Queens
# 2894  Springfield Gardens North         218    Queens
# 3071  Springfield Gardens North         218    Queens
# ...                         ...         ...       ...
# 2795                Parkchester         182     Bronx
# 2824            Jamaica Estates         131    Queens
# 2903                    Bayside          16    Queens
# 2926                    Maspeth         157    Queens
# 2930                  Homecrest         123  Brooklyn
#
# [3318 rows x 7 columns]

# %%
result['Wifi Type'] = result['Wifi Type'].str.replace('^(.*)$', r'\1 Wifi', regex=True)

# %%
result
# Out:
#                                      Name  Longitude   Latitude  \
# 0                       Baisley Pond Park -73.784120  40.674860
# 1283                    Baisley Pond Park -73.786780  40.672680
# 2322                    Baisley Pond Park -73.785170  40.673180
# 2894                     Rochdale Village -73.770590  40.672875
# 3071                    Baisley Pond Park -73.782540  40.676090
# ...                                   ...        ...        ...
# 2795                          Parkchester -73.858355  40.833736
# 2824                               Hollis -73.762304  40.720168
# 2903                              Bayside -73.768362  40.760126
# 2926                              Maspeth -73.893105  40.726995
# 2930  Homecrest - Brooklyn Public Library -73.960599  40.595237
#
#               Wifi Type                       zone location_id   borough
# 0     Limited Free Wifi  Springfield Gardens North         218    Queens
# 1283  Limited Free Wifi  Springfield Gardens North         218    Queens
# 2322  Limited Free Wifi  Springfield Gardens North         218    Queens
# 2894          Free Wifi  Springfield Gardens North         218    Queens
# 3071  Limited Free Wifi  Springfield Gardens North         218    Queens
# ...                 ...                        ...         ...       ...
# 2795          Free Wifi                Parkchester         182     Bronx
# 2824          Free Wifi            Jamaica Estates         131    Queens
# 2903          Free Wifi                    Bayside          16    Queens
# 2926          Free Wifi                    Maspeth         157    Queens
# 2930          Free Wifi                  Homecrest         123  Brooklyn
#
# [3318 rows x 7 columns]

# %%
result = result[['Wifi Type', 'location_id']]
result
# Out:
#               Wifi Type location_id
# 0     Limited Free Wifi         218
# 1283  Limited Free Wifi         218
# 2322  Limited Free Wifi         218
# 2894          Free Wifi         218
# 3071  Limited Free Wifi         218
# ...                 ...         ...
# 2795          Free Wifi         182
# 2824          Free Wifi         131
# 2903          Free Wifi          16
# 2926          Free Wifi         157
# 2930          Free Wifi         123
#
# [3318 rows x 2 columns]

# %%
result['Wifi Type'] = result['Wifi Type'].astype(str)
result['location_id'] = result['location_id'].astype(str)
# Out:
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40796/3110583916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['Wifi Type'] = result['Wifi Type'].astype(str)
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40796/3110583916.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['location_id'] = result['location_id'].astype(str)

# %%
df_combined = result.groupby(['location_id', 'Wifi Type']).size().reset_index(name='Counts')

df_combined
# Out:
#     location_id          Wifi Type  Counts
# 0            10          Free Wifi       1
# 1            10  Limited Free Wifi      16
# 2           100          Free Wifi      21
# 3           101          Free Wifi       1
# 4           102          Free Wifi       1
# ..          ...                ...     ...
# 304          94          Free Wifi       9
# 305          95          Free Wifi      30
# 306          97          Free Wifi      46
# 307          98          Free Wifi       2
# 308          98  Limited Free Wifi       7
#
# [309 rows x 3 columns]

# %%
df_combined.to_csv("basic_hotspot_df.csv", index=False)
