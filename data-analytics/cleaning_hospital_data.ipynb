# %%
import numpy as np
import pandas as pd
import pyarrow as pa
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NYC_Health___Hospitals_Facilities_-_2011.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
df
# Out:
#           Facility Type    Borough                             Facility Name  \
# 0   Child Health Center  Manhattan                     La Clinica Del Barrio
# 1   Acute Care Hospital     Queens                  Elmhurst Hospital Center
# 2   Child Health Center   Brooklyn     Ida G. Israel Community Health Center
# 3   Child Health Center     Queens      South Queens Community Health Center
# 4   Child Health Center      Bronx        Melrose Houses Child Health Clinic
# ..                  ...        ...                                       ...
# 73  Child Health Center   Brooklyn          Bushwick Community Health Center
# 74  Child Health Center  Manhattan                  Bellevue Hospital Center
# 75  Child Health Center     Queens              Ridgewood Communicare Clinic
# 76  Child Health Center  Manhattan           Smith Communicare Health Center
# 77  Child Health Center      Bronx  Morrisania Diagnostic & Treatment Center
#
#                             Cross Streets         Phone  \
# 0                                     NaN  212-410-7940
# 1                                     NaN  718-334-4000
# 2               W. 22nd St. & W. 23rd St.  718-946-3400
# 3                                     NaN  718-883-6699
# 4   between Morris Ave. & Courtlandt Ave.  718-292-2820
# ..                                    ...           ...
# 73                                    NaN  718-919-1200
# 74                                    NaN  212-562-4141
# 75     between Woodbine St. & Madison St.  718-334-6190
# 76                corner of Catherine St.  212-346-0500
# 77                                    NaN  718-960-2777
#
#                                            Location 1  Postcode   Latitude  \
# 0   413 120th Street\nNew York, NY 10035\n(40.7982...       NaN        NaN
# 1   79 01\nElmhurst, NY 11373\n(40.738710402563, -...       NaN        NaN
# 2   2201 Neptune Avenue\nBrooklyn, NY 11224\n(40.5...   11224.0  40.578468
# 3   114 02 Guy R Brewer Blvd\nJamaica, NY 11434\n(...   11434.0  40.688615
# 4   348 156th Street\nBronx, NY 10451\n(40.8213011...       NaN        NaN
# ..                                                ...       ...        ...
# 73  1420 Bushwick Avenue\nBrooklyn, NY 11207\n(40....   11207.0  40.684318
# 74  462 First Avenue\nNew York, NY 10016\n(40.7396...   10016.0  40.739173
# 75  769 Onderdonk Avenue\nRidgewood, NY 11385\n(40...   11385.0  40.702972
# 76  60 Madison Street\nNew York, NY 10038\n(40.711...   10038.0  40.712019
# 77  1225 Gerard Avenue\nBronx, NY 10452\n(40.83590...   10452.0  40.835957
#
#     Longitude  Community Board  Council District  Census Tract        BIN  \
# 0         NaN              NaN               NaN           NaN        NaN
# 1         NaN              NaN               NaN           NaN        NaN
# 2  -73.989614             13.0              47.0         348.0  3188417.0
# 3  -73.785593             12.0              28.0         276.0  4264631.0
# 4         NaN              NaN               NaN           NaN        NaN
# ..        ...              ...               ...           ...        ...
# 73 -73.909056              4.0              37.0         403.0  3080067.0
# 74 -73.976862              6.0               4.0          62.0  1086515.0
# 75 -73.905489              5.0              34.0         549.0  4083018.0
# 76 -73.997309              3.0               1.0          25.0  1077421.0
# 77 -73.919986              4.0              16.0         197.0  2003015.0
#
#              BBL                                                NTA
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2   3.069900e+09  Seagate-Coney Island                          ...
# 3   4.122000e+09  Baisley Park                                  ...
# 4            NaN                                                NaN
# ..           ...                                                ...
# 73  3.034440e+09  Bushwick South                                ...
# 74  1.009620e+09  Murray Hill-Kips Bay                          ...
# 75  4.034700e+09  Ridgewood                                     ...
# 76  1.001110e+09  Chinatown                                     ...
# 77  2.024890e+09  West Concourse                                ...
#
# [78 rows x 15 columns]

# %%
df.shape
# Out:
# (78, 15)

# %%
# check duplicated rows
print('Number of duplicate (excluding original) rows is:', df.duplicated().sum())
print('Number of duplicate rows (including first) in the table is:', df[df.duplicated(keep=False)].shape[0])
# Show duplicate row data that can be dropped
df[df.duplicated(keep=False)]
# Out:
# Number of duplicate (excluding original) rows is: 0
# Number of duplicate rows (including first) in the table is: 0
# Empty DataFrame
# Columns: [Facility Type, Borough, Facility Name, Cross Streets, Phone, Location 1, Postcode, Latitude, Longitude, Community Board, Council District, Census Tract, BIN, BBL, NTA]
# Index: []

# %%
df = df[['Facility Name', 'Facility Type', 'Borough', 'Longitude', 'Latitude']]

# %%
df
# Out:
#                                Facility Name        Facility Type    Borough  \
# 0                      La Clinica Del Barrio  Child Health Center  Manhattan
# 1                   Elmhurst Hospital Center  Acute Care Hospital     Queens
# 2      Ida G. Israel Community Health Center  Child Health Center   Brooklyn
# 3       South Queens Community Health Center  Child Health Center     Queens
# 4         Melrose Houses Child Health Clinic  Child Health Center      Bronx
# ..                                       ...                  ...        ...
# 73          Bushwick Community Health Center  Child Health Center   Brooklyn
# 74                  Bellevue Hospital Center  Child Health Center  Manhattan
# 75              Ridgewood Communicare Clinic  Child Health Center     Queens
# 76           Smith Communicare Health Center  Child Health Center  Manhattan
# 77  Morrisania Diagnostic & Treatment Center  Child Health Center      Bronx
#
#     Longitude   Latitude
# 0         NaN        NaN
# 1         NaN        NaN
# 2  -73.989614  40.578468
# 3  -73.785593  40.688615
# 4         NaN        NaN
# ..        ...        ...
# 73 -73.909056  40.684318
# 74 -73.976862  40.739173
# 75 -73.905489  40.702972
# 76 -73.997309  40.712019
# 77 -73.919986  40.835957
#
# [78 rows x 5 columns]

# %%
df[df['Longitude'].isnull() | df['Latitude'].isnull()]
# Out:
#                                         Facility Name  \
# 0                               La Clinica Del Barrio
# 1                            Elmhurst Hospital Center
# 4                  Melrose Houses Child Health Clinic
# 5           Daniel Webster Houses Child Health Clinic
# 6   Segundo Ruiz Belvis Diagnostic & Treatment Center
# 9            Cumberland Diagnostic & Treatment Center
# 21                             Sydenham Health Center
# 23           Lincoln  Medical &  Mental Health Center
# 27  Segundo Ruiz Belvis Diagnostic & Treatment Center
# 29  Renaissance Health Care Network Diagnostic & T...
# 30        Washington Heights Child Health Care Center
# 32           Cumberland Diagnostic & Treatment Center
# 33  Renaissance Health Care Network Diagnostic & T...
# 38                     Roberto Clemente Health Center
# 47                           Elmhurst Hospital Center
# 48                      Homecrest Child Health Clinic
# 63           Lincoln Medical and Mental Health Center
# 70  Manhattanville/St. Nicholas Houses Child Healt...
#
#                     Facility Type    Borough  Longitude  Latitude
# 0             Child Health Center  Manhattan        NaN       NaN
# 1             Acute Care Hospital     Queens        NaN       NaN
# 4             Child Health Center      Bronx        NaN       NaN
# 5             Child Health Center      Bronx        NaN       NaN
# 6   Diagnostic & Treatment Center      Bronx        NaN       NaN
# 9             Child Health Center   Brooklyn        NaN       NaN
# 21            Child Health Center  Manhattan        NaN       NaN
# 23            Child Health Center      Bronx        NaN       NaN
# 27            Child Health Center      Bronx        NaN       NaN
# 29            Child Health Center  Manhattan        NaN       NaN
# 30            Child Health Center  Manhattan        NaN       NaN
# 32  Diagnostic & Treatment Center   Brooklyn        NaN       NaN
# 33  Diagnostic & Treatment Center  Manhattan        NaN       NaN
# 38            Child Health Center  Manhattan        NaN       NaN
# 47            Child Health Center     Queens        NaN       NaN
# 48            Child Health Center   Brooklyn        NaN       NaN
# 63            Acute Care Hospital      Bronx        NaN       NaN
# 70            Child Health Center  Manhattan        NaN       NaN

# %%
borough_lat_long = {
    'Manhattan': {'Longitude':-73.971321, 'Latitude': 40.776676},
    'Brooklyn': {'Longitude':-73.949997, 'Latitude': 40.650002},
    'Bronx': {'Longitude':-73.865433, 'Latitude': 40.837048},
    'Queens': {'Longitude':-73.769417, 'Latitude': 40.742054}
}

# %%
for index, row in df.iterrows():
    borough = row['Borough']
    if pd.isna(row['Longitude']) and pd.isna(row['Latitude']):
        if borough in borough_lat_long:
            coordinates = borough_lat_long[borough]
            df.loc[index, 'Longitude'] = coordinates['Longitude']
            df.loc[index, 'Latitude'] = coordinates['Latitude']

print(df)
# Out:
#                                Facility Name        Facility Type    Borough  \
# 0                      La Clinica Del Barrio  Child Health Center  Manhattan
# 1                   Elmhurst Hospital Center  Acute Care Hospital     Queens
# 2      Ida G. Israel Community Health Center  Child Health Center   Brooklyn
# 3       South Queens Community Health Center  Child Health Center     Queens
# 4         Melrose Houses Child Health Clinic  Child Health Center      Bronx
# ..                                       ...                  ...        ...
# 73          Bushwick Community Health Center  Child Health Center   Brooklyn
# 74                  Bellevue Hospital Center  Child Health Center  Manhattan
# 75              Ridgewood Communicare Clinic  Child Health Center     Queens
# 76           Smith Communicare Health Center  Child Health Center  Manhattan
# 77  Morrisania Diagnostic & Treatment Center  Child Health Center      Bronx
#
#     Longitude   Latitude
# 0  -73.971321  40.776676
# 1  -73.769417  40.742054
# 2  -73.989614  40.578468
# 3  -73.785593  40.688615
# 4  -73.865433  40.837048
# ..        ...        ...
# 73 -73.909056  40.684318
# 74 -73.976862  40.739173
# 75 -73.905489  40.702972
# 76 -73.997309  40.712019
# 77 -73.919986  40.835957
#
# [78 rows x 5 columns]

# %%
df
# Out:
#                                Facility Name        Facility Type    Borough  \
# 0                      La Clinica Del Barrio  Child Health Center  Manhattan
# 1                   Elmhurst Hospital Center  Acute Care Hospital     Queens
# 2      Ida G. Israel Community Health Center  Child Health Center   Brooklyn
# 3       South Queens Community Health Center  Child Health Center     Queens
# 4         Melrose Houses Child Health Clinic  Child Health Center      Bronx
# ..                                       ...                  ...        ...
# 73          Bushwick Community Health Center  Child Health Center   Brooklyn
# 74                  Bellevue Hospital Center  Child Health Center  Manhattan
# 75              Ridgewood Communicare Clinic  Child Health Center     Queens
# 76           Smith Communicare Health Center  Child Health Center  Manhattan
# 77  Morrisania Diagnostic & Treatment Center  Child Health Center      Bronx
#
#     Longitude   Latitude
# 0  -73.971321  40.776676
# 1  -73.769417  40.742054
# 2  -73.989614  40.578468
# 3  -73.785593  40.688615
# 4  -73.865433  40.837048
# ..        ...        ...
# 73 -73.909056  40.684318
# 74 -73.976862  40.739173
# 75 -73.905489  40.702972
# 76 -73.997309  40.712019
# 77 -73.919986  40.835957
#
# [78 rows x 5 columns]

# %%
df[df['Longitude'].isnull() | df['Latitude'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Facility Name, Facility Type, Borough, Longitude, Latitude]
# Index: []

# %%
df.isnull().sum()
# Out:
# Facility Name    0
# Facility Type    0
# Borough          0
# Longitude        0
# Latitude         0
# dtype: int64

# %%
# check the data type
df.dtypes
# Out:
# Facility Name     object
# Facility Type     object
# Borough           object
# Longitude        float64
# Latitude         float64
# dtype: object

# %%
df['Industry'] = 'Health Care'
# Out:
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40804/1033874757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Industry'] = 'Health Care'

# %%
df
# Out:
#                                Facility Name        Facility Type    Borough  \
# 0                      La Clinica Del Barrio  Child Health Center  Manhattan
# 1                   Elmhurst Hospital Center  Acute Care Hospital     Queens
# 2      Ida G. Israel Community Health Center  Child Health Center   Brooklyn
# 3       South Queens Community Health Center  Child Health Center     Queens
# 4         Melrose Houses Child Health Clinic  Child Health Center      Bronx
# ..                                       ...                  ...        ...
# 73          Bushwick Community Health Center  Child Health Center   Brooklyn
# 74                  Bellevue Hospital Center  Child Health Center  Manhattan
# 75              Ridgewood Communicare Clinic  Child Health Center     Queens
# 76           Smith Communicare Health Center  Child Health Center  Manhattan
# 77  Morrisania Diagnostic & Treatment Center  Child Health Center      Bronx
#
#     Longitude   Latitude     Industry
# 0  -73.971321  40.776676  Health Care
# 1  -73.769417  40.742054  Health Care
# 2  -73.989614  40.578468  Health Care
# 3  -73.785593  40.688615  Health Care
# 4  -73.865433  40.837048  Health Care
# ..        ...        ...          ...
# 73 -73.909056  40.684318  Health Care
# 74 -73.976862  40.739173  Health Care
# 75 -73.905489  40.702972  Health Care
# 76 -73.997309  40.712019  Health Care
# 77 -73.919986  40.835957  Health Care
#
# [78 rows x 6 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
# change 'Longitude' and 'Latitude' into GeoDataFrame
df['Coordinates'] = list(zip(df.Longitude, df.Latitude))
df['Coordinates'] = df['Coordinates'].apply(Point)

gdf_HealthCare = gpd.GeoDataFrame(df, geometry='Coordinates')
# Out:
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40804/977630074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Coordinates'] = list(zip(df.Longitude, df.Latitude))
# /var/folders/b7/hypfklws4tbd7gw4p0ymc8sr0000gn/T/ipykernel_40804/977630074.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Coordinates'] = df['Coordinates'].apply(Point)

# %%
gdf_HealthCare
# Out:
#                                Facility Name        Facility Type    Borough  \
# 0                      La Clinica Del Barrio  Child Health Center  Manhattan
# 1                   Elmhurst Hospital Center  Acute Care Hospital     Queens
# 2      Ida G. Israel Community Health Center  Child Health Center   Brooklyn
# 3       South Queens Community Health Center  Child Health Center     Queens
# 4         Melrose Houses Child Health Clinic  Child Health Center      Bronx
# ..                                       ...                  ...        ...
# 73          Bushwick Community Health Center  Child Health Center   Brooklyn
# 74                  Bellevue Hospital Center  Child Health Center  Manhattan
# 75              Ridgewood Communicare Clinic  Child Health Center     Queens
# 76           Smith Communicare Health Center  Child Health Center  Manhattan
# 77  Morrisania Diagnostic & Treatment Center  Child Health Center      Bronx
#
#     Longitude   Latitude     Industry                 Coordinates
# 0  -73.971321  40.776676  Health Care  POINT (-73.97132 40.77668)
# 1  -73.769417  40.742054  Health Care  POINT (-73.76942 40.74205)
# 2  -73.989614  40.578468  Health Care  POINT (-73.98961 40.57847)
# 3  -73.785593  40.688615  Health Care  POINT (-73.78559 40.68861)
# 4  -73.865433  40.837048  Health Care  POINT (-73.86543 40.83705)
# ..        ...        ...          ...                         ...
# 73 -73.909056  40.684318  Health Care  POINT (-73.90906 40.68432)
# 74 -73.976862  40.739173  Health Care  POINT (-73.97686 40.73917)
# 75 -73.905489  40.702972  Health Care  POINT (-73.90549 40.70297)
# 76 -73.997309  40.712019  Health Care  POINT (-73.99731 40.71202)
# 77 -73.919986  40.835957  Health Care  POINT (-73.91999 40.83596)
#
# [78 rows x 7 columns]

# %%
# Read the geojson file
taxi_zone = gpd.read_file('NYC Taxi Zones.geojson')
taxi_zone
# Out:
#              shape_area objectid       shape_leng location_id  \
# 0       0.0007823067885        1   0.116357453189           1
# 1      0.00486634037837        2    0.43346966679           2
# 2     0.000314414156821        3  0.0843411059012           3
# 3     0.000111871946192        4  0.0435665270921           4
# 4     0.000497957489363        5  0.0921464898574           5
# ..                  ...      ...              ...         ...
# 258   0.000168611097013      256  0.0679149669603         256
# 259   0.000394552487366      259   0.126750305191         259
# 260   0.000422345326907      260   0.133514154636         260
# 261  0.0000343423231652      261  0.0271204563616         261
# 262   0.000122330270966      262  0.0490636231541         262
#
#                           zone        borough  \
# 0               Newark Airport            EWR
# 1                  Jamaica Bay         Queens
# 2      Allerton/Pelham Gardens          Bronx
# 3                Alphabet City      Manhattan
# 4                Arden Heights  Staten Island
# ..                         ...            ...
# 258  Williamsburg (South Side)       Brooklyn
# 259         Woodlawn/Wakefield          Bronx
# 260                   Woodside         Queens
# 261         World Trade Center      Manhattan
# 262             Yorkville East      Manhattan
#
#                                               geometry
# 0    MULTIPOLYGON (((-74.18445 40.69500, -74.18449 ...
# 1    MULTIPOLYGON (((-73.82338 40.63899, -73.82277 ...
# 2    MULTIPOLYGON (((-73.84793 40.87134, -73.84725 ...
# 3    MULTIPOLYGON (((-73.97177 40.72582, -73.97179 ...
# 4    MULTIPOLYGON (((-74.17422 40.56257, -74.17349 ...
# ..                                                 ...
# 258  MULTIPOLYGON (((-73.95834 40.71331, -73.95681 ...
# 259  MULTIPOLYGON (((-73.85107 40.91037, -73.85207 ...
# 260  MULTIPOLYGON (((-73.90175 40.76078, -73.90147 ...
# 261  MULTIPOLYGON (((-74.01333 40.70503, -74.01327 ...
# 262  MULTIPOLYGON (((-73.94383 40.78286, -73.94376 ...
#
# [263 rows x 7 columns]

# %%
gdf_taxi_zone = gpd.GeoDataFrame(taxi_zone, geometry='geometry')
gdf_taxi_zone
# Out:
#              shape_area objectid       shape_leng location_id  \
# 0       0.0007823067885        1   0.116357453189           1
# 1      0.00486634037837        2    0.43346966679           2
# 2     0.000314414156821        3  0.0843411059012           3
# 3     0.000111871946192        4  0.0435665270921           4
# 4     0.000497957489363        5  0.0921464898574           5
# ..                  ...      ...              ...         ...
# 258   0.000168611097013      256  0.0679149669603         256
# 259   0.000394552487366      259   0.126750305191         259
# 260   0.000422345326907      260   0.133514154636         260
# 261  0.0000343423231652      261  0.0271204563616         261
# 262   0.000122330270966      262  0.0490636231541         262
#
#                           zone        borough  \
# 0               Newark Airport            EWR
# 1                  Jamaica Bay         Queens
# 2      Allerton/Pelham Gardens          Bronx
# 3                Alphabet City      Manhattan
# 4                Arden Heights  Staten Island
# ..                         ...            ...
# 258  Williamsburg (South Side)       Brooklyn
# 259         Woodlawn/Wakefield          Bronx
# 260                   Woodside         Queens
# 261         World Trade Center      Manhattan
# 262             Yorkville East      Manhattan
#
#                                               geometry
# 0    MULTIPOLYGON (((-74.18445 40.69500, -74.18449 ...
# 1    MULTIPOLYGON (((-73.82338 40.63899, -73.82277 ...
# 2    MULTIPOLYGON (((-73.84793 40.87134, -73.84725 ...
# 3    MULTIPOLYGON (((-73.97177 40.72582, -73.97179 ...
# 4    MULTIPOLYGON (((-74.17422 40.56257, -74.17349 ...
# ..                                                 ...
# 258  MULTIPOLYGON (((-73.95834 40.71331, -73.95681 ...
# 259  MULTIPOLYGON (((-73.85107 40.91037, -73.85207 ...
# 260  MULTIPOLYGON (((-73.90175 40.76078, -73.90147 ...
# 261  MULTIPOLYGON (((-74.01333 40.70503, -74.01327 ...
# 262  MULTIPOLYGON (((-73.94383 40.78286, -73.94376 ...
#
# [263 rows x 7 columns]

# %%
# Ensure both GeoDataFrames are using the same CRS
gdf_HealthCare = gdf_HealthCare.set_crs("EPSG:4326")
gdf_taxi_zone = gdf_taxi_zone.set_crs("EPSG:4326")

# Perform spatial join with the 'predicate' parameter
result = gpd.sjoin(gdf_HealthCare, gdf_taxi_zone, how="inner", predicate='intersects')

# %%
result
# Out:
#                                         Facility Name  \
# 0                               La Clinica Del Barrio
# 21                             Sydenham Health Center
# 29  Renaissance Health Care Network Diagnostic & T...
# 30        Washington Heights Child Health Care Center
# 33  Renaissance Health Care Network Diagnostic & T...
# ..                                                ...
# 62                Woodside Houses Child Health Clinic
# 66                           Health Center at Tremont
# 68                  Crown Heights Child Health Clinic
# 75                       Ridgewood Communicare Clinic
# 76                    Smith Communicare Health Center
#
#                     Facility Type    Borough  Longitude   Latitude  \
# 0             Child Health Center  Manhattan -73.971321  40.776676
# 21            Child Health Center  Manhattan -73.971321  40.776676
# 29            Child Health Center  Manhattan -73.971321  40.776676
# 30            Child Health Center  Manhattan -73.971321  40.776676
# 33  Diagnostic & Treatment Center  Manhattan -73.971321  40.776676
# ..                            ...        ...        ...        ...
# 62            Child Health Center     Queens -73.910752  40.753164
# 66            Child Health Center      Bronx -73.894482  40.844083
# 68            Child Health Center   Brooklyn -73.935845  40.673530
# 75            Child Health Center     Queens -73.905489  40.702972
# 76            Child Health Center  Manhattan -73.997309  40.712019
#
#        Industry                 Coordinates  index_right          shape_area  \
# 0   Health Care  POINT (-73.97132 40.77668)           44   0.000379662912054
# 21  Health Care  POINT (-73.97132 40.77668)           44   0.000379662912054
# 29  Health Care  POINT (-73.97132 40.77668)           44   0.000379662912054
# 30  Health Care  POINT (-73.97132 40.77668)           44   0.000379662912054
# 33  Health Care  POINT (-73.97132 40.77668)           44   0.000379662912054
# ..          ...                         ...          ...                 ...
# 62  Health Care  POINT (-73.91075 40.75316)            6   0.000389787989274
# 66  Health Care  POINT (-73.89448 40.84408)           81   0.000191114419551
# 68  Health Care  POINT (-73.93585 40.67353)           60   0.000510772092295
# 75  Health Care  POINT (-73.90549 40.70297)          198   0.000499809882564
# 76  Health Care  POINT (-73.99731 40.71202)           41  0.0000913594688556
#
#    objectid       shape_leng location_id                 zone    borough
# 0        43  0.0997386183576          43         Central Park  Manhattan
# 21       43  0.0997386183576          43         Central Park  Manhattan
# 29       43  0.0997386183576          43         Central Park  Manhattan
# 30       43  0.0997386183576          43         Central Park  Manhattan
# 33       43  0.0997386183576          43         Central Park  Manhattan
# ..      ...              ...         ...                  ...        ...
# 62        7   0.107417171123           7              Astoria     Queens
# 66       78  0.0935944495806          78         East Tremont      Bronx
# 68       61   0.117310808097          61  Crown Heights North   Brooklyn
# 75      198   0.134094242763         198            Ridgewood     Queens
# 76       45  0.0459068626235          45            Chinatown  Manhattan
#
# [78 rows x 14 columns]

# %%
result = result[['Facility Name', 'Facility Type', 'Industry', 'Longitude', 'Latitude', 'zone', "location_id", "borough" ]]
result
# Out:
#                                         Facility Name  \
# 0                               La Clinica Del Barrio
# 21                             Sydenham Health Center
# 29  Renaissance Health Care Network Diagnostic & T...
# 30        Washington Heights Child Health Care Center
# 33  Renaissance Health Care Network Diagnostic & T...
# ..                                                ...
# 62                Woodside Houses Child Health Clinic
# 66                           Health Center at Tremont
# 68                  Crown Heights Child Health Clinic
# 75                       Ridgewood Communicare Clinic
# 76                    Smith Communicare Health Center
#
#                     Facility Type     Industry  Longitude   Latitude  \
# 0             Child Health Center  Health Care -73.971321  40.776676
# 21            Child Health Center  Health Care -73.971321  40.776676
# 29            Child Health Center  Health Care -73.971321  40.776676
# 30            Child Health Center  Health Care -73.971321  40.776676
# 33  Diagnostic & Treatment Center  Health Care -73.971321  40.776676
# ..                            ...          ...        ...        ...
# 62            Child Health Center  Health Care -73.910752  40.753164
# 66            Child Health Center  Health Care -73.894482  40.844083
# 68            Child Health Center  Health Care -73.935845  40.673530
# 75            Child Health Center  Health Care -73.905489  40.702972
# 76            Child Health Center  Health Care -73.997309  40.712019
#
#                    zone location_id    borough
# 0          Central Park          43  Manhattan
# 21         Central Park          43  Manhattan
# 29         Central Park          43  Manhattan
# 30         Central Park          43  Manhattan
# 33         Central Park          43  Manhattan
# ..                  ...         ...        ...
# 62              Astoria           7     Queens
# 66         East Tremont          78      Bronx
# 68  Crown Heights North          61   Brooklyn
# 75            Ridgewood         198     Queens
# 76            Chinatown          45  Manhattan
#
# [78 rows x 8 columns]

# %%
result.isnull().sum()
# Out:
# Facility Name    0
# Facility Type    0
# Borough          0
# Longitude        0
# Latitude         0
# Industry         0
# Coordinates      0
# index_right      0
# shape_area       0
# objectid         0
# shape_leng       0
# location_id      0
# zone             0
# borough          0
# dtype: int64

# %% [markdown]
# # the code below used for model

# %%
result = result[['Industry', 'Facility Type','location_id']]
result
# Out:
#        Industry                  Facility Type location_id
# 0   Health Care            Child Health Center          43
# 21  Health Care            Child Health Center          43
# 29  Health Care            Child Health Center          43
# 30  Health Care            Child Health Center          43
# 33  Health Care  Diagnostic & Treatment Center          43
# ..          ...                            ...         ...
# 62  Health Care            Child Health Center           7
# 66  Health Care            Child Health Center          78
# 68  Health Care            Child Health Center          61
# 75  Health Care            Child Health Center         198
# 76  Health Care            Child Health Center          45
#
# [78 rows x 3 columns]

# %%
df_combined_Industry = result.groupby(['location_id', 'Industry']).size().reset_index(name='Counts')

df_combined_Industry
# Out:
#    location_id     Industry  Counts
# 0           10  Health Care       1
# 1          112  Health Care       1
# 2          118  Health Care       1
# 3          121  Health Care       2
# 4          127  Health Care       1
# 5          130  Health Care       1
# 6          137  Health Care       2
# 7          144  Health Care       1
# 8          156  Health Care       1
# 9          166  Health Care       1
# 10          17  Health Care       1
# 11         173  Health Care       1
# 12         174  Health Care       2
# 13         185  Health Care       2
# 14         188  Health Care       3
# 15         198  Health Care       1
# 16         202  Health Care       2
# 17         205  Health Care       1
# 18         221  Health Care       1
# 19         225  Health Care       2
# 20         232  Health Care       4
# 21         247  Health Care       2
# 22         248  Health Care       6
# 23         254  Health Care       1
# 24         255  Health Care       1
# 25          29  Health Care       2
# 26          35  Health Care       1
# 27          37  Health Care       4
# 28          42  Health Care       3
# 29          43  Health Care       7
# 30          45  Health Care       1
# 31          55  Health Care       1
# 32          56  Health Care       1
# 33          61  Health Care       1
# 34          65  Health Care       1
# 35           7  Health Care       1
# 36          75  Health Care       2
# 37          76  Health Care       1
# 38          77  Health Care       2
# 39          78  Health Care       1
# 40          80  Health Care       2
# 41          85  Health Care       3
# 42          98  Health Care       2

# %%
df_combined_FacilityType = result.groupby(['location_id', 'Facility Type']).size().reset_index(name='Counts')

df_combined_FacilityType
# Out:
#    location_id                  Facility Type  Counts
# 0           10            Child Health Center       1
# 1          112            Child Health Center       1
# 2          118                   Nursing Home       1
# 3          121            Acute Care Hospital       1
# 4          121            Child Health Center       1
# ..         ...                            ...     ...
# 57          80            Child Health Center       2
# 58          85            Child Health Center       2
# 59          85  Diagnostic & Treatment Center       1
# 60          98            Acute Care Hospital       1
# 61          98            Child Health Center       1
#
# [62 rows x 3 columns]

# %%
# check the outcome is correct
total_count = df_combined_FacilityType['Counts'].sum()
total_count
# Out:
# 78

# %%
df_combined_Industry.to_csv("basic_HospitalData_version_1.csv", index=False)

# %%
df_combined_FacilityType.to_csv("basic_HospitalData_version_2.csv", index=False)
