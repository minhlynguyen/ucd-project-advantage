# %%
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
#Import package matplotlib for visualisation/plotting
# import matplotlib.pyplot as plt

# %% [markdown]
# # open all the yellow and green taxi file and save them into dataframe

# %%
raw = pd.DataFrame()
combine_raw = pd.DataFrame()
for year in range(2022, 2024):
    for month in range(1, 13):
        if (year == 2023 and month in range (5,13)):
            pass
        else:
            # Make sure the month is two digits        
            month = str(month).zfill(2)
            yellow_file_name = f'yellow_tripdata_{year}-{month}.parquet'
            print(yellow_file_name)

            try:
                raw_yellow_partition = pq.read_table(yellow_file_name)
                raw_yellow_partition = raw_yellow_partition.to_pandas()
    #             [['tpep_pickup_datetime','tpep_dropoff_datetime',
    #                                                     'passenger_count','PULocationID','DOLocationID']]
            except Exception as e:
                    print(f"Could not read file: {yellow_file_name}. Error: {e}")

            green_file_name = f'green_tripdata_{year}-{month}.parquet'
            print(green_file_name)

            try:
                raw_green_partition = pq.read_table(green_file_name)
                raw_green_partition = raw_green_partition.to_pandas()
    #             [['lpep_pickup_datetime','lpep_dropoff_datetime',
    #                                                     'passenger_count','PULocationID','DOLocationID']]

                raw_green_partition.columns = raw_green_partition.columns.str.replace('lpep_pickup_datetime', 'tpep_pickup_datetime')
                raw_green_partition.columns = raw_green_partition.columns.str.replace('lpep_dropoff_datetime', 'tpep_dropoff_datetime')
            except Exception as e:
                    print(f"Could not read file: {green_file_name}. Error: {e}")

            raw = pd.concat([raw,raw_yellow_partition, raw_green_partition],axis=0)
raw.shape
# Out:
# yellow_tripdata_2022-01.parquet
# green_tripdata_2022-01.parquet
# yellow_tripdata_2022-02.parquet
# green_tripdata_2022-02.parquet
# yellow_tripdata_2022-03.parquet
# green_tripdata_2022-03.parquet
# yellow_tripdata_2022-04.parquet
# green_tripdata_2022-04.parquet
# yellow_tripdata_2022-05.parquet
# green_tripdata_2022-05.parquet
# yellow_tripdata_2022-06.parquet
# green_tripdata_2022-06.parquet
# yellow_tripdata_2022-07.parquet
# green_tripdata_2022-07.parquet
# yellow_tripdata_2022-08.parquet
# green_tripdata_2022-08.parquet
# yellow_tripdata_2022-09.parquet
# green_tripdata_2022-09.parquet
# yellow_tripdata_2022-10.parquet
# green_tripdata_2022-10.parquet
# yellow_tripdata_2022-11.parquet
# green_tripdata_2022-11.parquet
# yellow_tripdata_2022-12.parquet
# green_tripdata_2022-12.parquet
# yellow_tripdata_2023-01.parquet
# green_tripdata_2023-01.parquet
# yellow_tripdata_2023-02.parquet
# green_tripdata_2023-02.parquet
# yellow_tripdata_2023-03.parquet
# green_tripdata_2023-03.parquet
# yellow_tripdata_2023-04.parquet
# green_tripdata_2023-04.parquet
# (53439693, 22)

# %% [markdown]
# # clean duplicated rows

# %%
# duplicated rows
duplicated = raw[raw.duplicated(keep=False)]
# Show duplicate row data that can be dropped
duplicated
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3022804         2  2022-10-27 15:22:53   2022-10-27 15:23:01              1.0
# 3022805         2  2022-10-27 15:22:53   2022-10-27 15:23:01              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 3022804            0.0         1.0                  N           193
# 3022805            0.0         1.0                  N           193
#
#          DOLocationID  payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 3022804           193           2.0  ...      0.5         0.0           0.0
# 3022805           193           2.0  ...      0.5         0.0           0.0
#
#          improvement_surcharge  total_amount  congestion_surcharge  \
# 3022804                    0.3           3.3                   0.0
# 3022805                    0.3           3.3                   0.0
#
#          airport_fee  ehail_fee  trip_type Airport_fee
# 3022804          0.0        NaN        NaN         NaN
# 3022805          0.0        NaN        NaN         NaN
#
# [2 rows x 22 columns]

# %%
print('Number of duplicate rows (including first) in the table is:')
duplicated.shape[0]
# Out:
# Number of duplicate rows (including first) in the table is:
# 2

# %% [markdown]
# No drop of duplication: High chances these 2 are different rides

# %% [markdown]
# # combine the pickup and dropoff data together

# %%
raw_pickup = raw[['tpep_pickup_datetime',
                                            'passenger_count','PULocationID']]
raw_pickup = raw_pickup.set_axis(['datetime', 'passenger_count', 'taxi_zone'], axis='columns')

raw_dropoff = raw[['tpep_dropoff_datetime',
                                            'passenger_count','DOLocationID']]
raw_dropoff = raw_dropoff.set_axis(['datetime', 'passenger_count', 'taxi_zone'], axis='columns')


combine_raw = pd.concat([raw_pickup,raw_dropoff],axis=0)
combine_raw
# Out:
#                  datetime  passenger_count  taxi_zone
# 0     2022-01-01 00:35:40              2.0        142
# 1     2022-01-01 00:33:43              1.0        236
# 2     2022-01-01 00:53:21              1.0        166
# 3     2022-01-01 00:25:21              1.0        114
# 4     2022-01-01 00:36:48              1.0         68
# ...                   ...              ...        ...
# 65387 2023-04-30 22:12:00              NaN        168
# 65388 2023-04-30 23:43:00              NaN        170
# 65389 2023-04-30 23:40:00              NaN        112
# 65390 2023-04-30 23:57:00              NaN        236
# 65391 2023-04-30 23:44:00              NaN         74
#
# [106879386 rows x 3 columns]

# %%
 # check null value
combine_raw.isnull().sum()
# Out:
# datetime                 0
# passenger_count    3607352
# taxi_zone                0
# dtype: int64

# %% [markdown]
# # replace the null value of passenger_count with median

# %%
# replace missing value with reasonable estimate -- median.
median_case_passenger_count = combine_raw['passenger_count'].median()
median_case_passenger_count
combine_raw['passenger_count'] = combine_raw['passenger_count'].replace(np.nan, median_case_passenger_count)

# %%
# check the missing value, make sure there is no missing value.
missing_case_passenger_count = combine_raw[combine_raw['passenger_count'].isnull()]
missing_case_passenger_count
# Out:
# Empty DataFrame
# Columns: [datetime, passenger_count, taxi_zone]
# Index: []

# %% [markdown]
# # replace the "0" value of passenger_count with median

# %%
# check the rows of 0 value.
zero_value_case_passenger_count = combine_raw[combine_raw['passenger_count'] == 0]
zero_value_case_passenger_count
# Out:
#                  datetime  passenger_count  taxi_zone
# 143   2022-01-01 00:17:34              0.0        236
# 144   2022-01-01 00:23:57              0.0        263
# 145   2022-01-01 00:31:53              0.0        140
# 146   2022-01-01 00:41:40              0.0        163
# 157   2022-01-01 00:55:36              0.0        162
# ...                   ...              ...        ...
# 60482 2023-04-30 17:20:44              0.0         65
# 60514 2023-04-30 18:46:26              0.0        238
# 60540 2023-04-30 18:49:55              0.0         97
# 60595 2023-04-30 18:21:29              0.0         52
# 60596 2023-04-30 18:26:49              0.0         25
#
# [1964792 rows x 3 columns]

# %%
combine_raw['passenger_count'] = combine_raw['passenger_count'].replace(0, median_case_passenger_count)

# %%
# check the rows of 0 value has been dropped.
zero_value_case_passenger_count = combine_raw[combine_raw['passenger_count'] == 0]
zero_value_case_passenger_count
# Out:
# Empty DataFrame
# Columns: [datetime, passenger_count, taxi_zone]
# Index: []

# %%
combine_raw.dtypes
# Out:
# datetime           datetime64[ns]
# passenger_count           float64
# taxi_zone                   int64
# dtype: object

# %%
combine_raw
# Out:
#                  datetime  passenger_count  taxi_zone
# 0     2022-01-01 00:35:40              2.0        142
# 1     2022-01-01 00:33:43              1.0        236
# 2     2022-01-01 00:53:21              1.0        166
# 3     2022-01-01 00:25:21              1.0        114
# 4     2022-01-01 00:36:48              1.0         68
# ...                   ...              ...        ...
# 65387 2023-04-30 22:12:00              1.0        168
# 65388 2023-04-30 23:43:00              1.0        170
# 65389 2023-04-30 23:40:00              1.0        112
# 65390 2023-04-30 23:57:00              1.0        236
# 65391 2023-04-30 23:44:00              1.0         74
#
# [106879386 rows x 3 columns]

# %% [markdown]
# # group the passenger number together by the hour

# %%
# change the time into hour, ignore the minutes and seconds
combine_raw['datetime'] = combine_raw['datetime'].dt.floor('H')

# %%
df_grouped = combine_raw.groupby(['taxi_zone', 'datetime'])['passenger_count'].sum().reset_index()

# %%
df_grouped
# Out:
#          taxi_zone            datetime  passenger_count
# 0                1 2002-10-25 09:00:00              4.0
# 1                1 2002-10-27 09:00:00              3.0
# 2                1 2002-10-28 04:00:00              1.0
# 3                1 2002-10-28 05:00:00              2.0
# 4                1 2009-01-02 00:00:00              2.0
# ...            ...                 ...              ...
# 2032351        265 2023-04-30 20:00:00             53.0
# 2032352        265 2023-04-30 21:00:00             49.0
# 2032353        265 2023-04-30 22:00:00             68.0
# 2032354        265 2023-04-30 23:00:00             95.0
# 2032355        265 2023-05-01 00:00:00             28.0
#
# [2032356 rows x 3 columns]

# %%
# Extract year and month
df_grouped['year_month'] = df_grouped['datetime'].dt.to_period('M')

# Extract day of week (Monday=0, Sunday=6)
# df_grouped['day'] = df_grouped['datetime'].dt.day

# Extract day of week (Monday=0, Sunday=6)
df_grouped['week'] = df_grouped['datetime'].dt.dayofweek

# Extract hour of the day
df_grouped['hour'] = df_grouped['datetime'].dt.hour

# days = {0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'}
# combine_raw['week'] = combine_raw['week'].apply(lambda x: days[x])

df_grouped
# Out:
#          taxi_zone            datetime  passenger_count year_month  week  hour
# 0                1 2002-10-25 09:00:00              4.0    2002-10     4     9
# 1                1 2002-10-27 09:00:00              3.0    2002-10     6     9
# 2                1 2002-10-28 04:00:00              1.0    2002-10     0     4
# 3                1 2002-10-28 05:00:00              2.0    2002-10     0     5
# 4                1 2009-01-02 00:00:00              2.0    2009-01     4     0
# ...            ...                 ...              ...        ...   ...   ...
# 2032351        265 2023-04-30 20:00:00             53.0    2023-04     6    20
# 2032352        265 2023-04-30 21:00:00             49.0    2023-04     6    21
# 2032353        265 2023-04-30 22:00:00             68.0    2023-04     6    22
# 2032354        265 2023-04-30 23:00:00             95.0    2023-04     6    23
# 2032355        265 2023-05-01 00:00:00             28.0    2023-05     0     0
#
# [2032356 rows x 6 columns]

# %%
df_grouped.reset_index(drop=True).to_parquet("basic_taxi_df.parquet", index=False)

# %%
df = pd.read_parquet("basic_taxi_df.parquet")
df
# Out:
#          taxi_zone            datetime  passenger_count year_month  week  hour
# 0                1 2002-10-25 09:00:00              4.0    2002-10     4     9
# 1                1 2002-10-27 09:00:00              3.0    2002-10     6     9
# 2                1 2002-10-28 04:00:00              1.0    2002-10     0     4
# 3                1 2002-10-28 05:00:00              2.0    2002-10     0     5
# 4                1 2009-01-02 00:00:00              2.0    2009-01     4     0
# ...            ...                 ...              ...        ...   ...   ...
# 2032351        265 2023-04-30 20:00:00             53.0    2023-04     6    20
# 2032352        265 2023-04-30 21:00:00             49.0    2023-04     6    21
# 2032353        265 2023-04-30 22:00:00             68.0    2023-04     6    22
# 2032354        265 2023-04-30 23:00:00             95.0    2023-04     6    23
# 2032355        265 2023-05-01 00:00:00             28.0    2023-05     0     0
#
# [2032356 rows x 6 columns]

# %%
df_grouped.to_json("basic_taxi_df.json", orient="index", default_handler=str)

# %%
import json
f = open('basic_taxi_df.json')
data = json.load(f)

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
data
# Out:
# {'0': {'taxi_zone': 1,
#   'datetime': 1035536400000,
#   'passenger_count': 4.0,
#   'year_month': '2002-10',
#   'week': 4,
#   'hour': 9},
#  '1': {'taxi_zone': 1,
#   'datetime': 1035709200000,
#   'passenger_count': 3.0,
#   'year_month': '2002-10',
#   'week': 6,
#   'hour': 9},
#  '2': {'taxi_zone': 1,
#   'datetime': 1035777600000,
#   'passenger_count': 1.0,
#   'year_month': '2002-10',
#   'week': 0,
#   'hour': 4},
#  '3': {'taxi_zone': 1,
#   'datetime': 1035781200000,
#   'passenger_count': 2.0,
#   'year_month': '2002-10',
#   'week': 0,
#   'hour': 5},
#  '4': {'taxi_zone': 1,
#   'datetime': 1230854400000,
#   'passenger_count': 2.0,
#   'year_month': '2009-01',
#   'week': 4,
#   'hour': 0},
#  '5': {'taxi_zone': 1,
#   'datetime': 1641002400000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 2},
#  '6': {'taxi_zone': 1,
#   'datetime': 1641006000000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 3},
#  '7': {'taxi_zone': 1,
#   'datetime': 1641009600000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 4},
#  '8': {'taxi_zone': 1,
#   'datetime': 1641013200000,
#   'passenger_count': 31.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 5},
#  '9': {'taxi_zone': 1,
#   'datetime': 1641016800000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 6},
#  '10': {'taxi_zone': 1,
#   'datetime': 1641020400000,
#   'passenger_count': 31.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 7},
#  '11': {'taxi_zone': 1,
#   'datetime': 1641024000000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 8},
#  '12': {'taxi_zone': 1,
#   'datetime': 1641027600000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 9},
#  '13': {'taxi_zone': 1,
#   'datetime': 1641031200000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 10},
#  '14': {'taxi_zone': 1,
#   'datetime': 1641034800000,
#   'passenger_count': 31.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 11},
#  '15': {'taxi_zone': 1,
#   'datetime': 1641038400000,
#   'passenger_count': 31.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 12},
#  '16': {'taxi_zone': 1,
#   'datetime': 1641042000000,
#   'passenger_count': 38.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 13},
#  '17': {'taxi_zone': 1,
#   'datetime': 1641045600000,
#   'passenger_count': 86.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 14},
#  '18': {'taxi_zone': 1,
#   'datetime': 1641049200000,
#   'passenger_count': 123.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 15},
#  '19': {'taxi_zone': 1,
#   'datetime': 1641052800000,
#   'passenger_count': 63.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 16},
#  '20': {'taxi_zone': 1,
#   'datetime': 1641056400000,
#   'passenger_count': 56.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 17},
#  '21': {'taxi_zone': 1,
#   'datetime': 1641060000000,
#   'passenger_count': 32.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 18},
#  '22': {'taxi_zone': 1,
#   'datetime': 1641063600000,
#   'passenger_count': 27.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 19},
#  '23': {'taxi_zone': 1,
#   'datetime': 1641067200000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 20},
#  '24': {'taxi_zone': 1,
#   'datetime': 1641085200000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 1},
#  '25': {'taxi_zone': 1,
#   'datetime': 1641092400000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 3},
#  '26': {'taxi_zone': 1,
#   'datetime': 1641096000000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 4},
#  '27': {'taxi_zone': 1,
#   'datetime': 1641099600000,
#   'passenger_count': 39.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 5},
#  '28': {'taxi_zone': 1,
#   'datetime': 1641103200000,
#   'passenger_count': 20.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 6},
#  '29': {'taxi_zone': 1,
#   'datetime': 1641106800000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 7},
#  '30': {'taxi_zone': 1,
#   'datetime': 1641110400000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 8},
#  '31': {'taxi_zone': 1,
#   'datetime': 1641114000000,
#   'passenger_count': 27.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 9},
#  '32': {'taxi_zone': 1,
#   'datetime': 1641117600000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 10},
#  '33': {'taxi_zone': 1,
#   'datetime': 1641121200000,
#   'passenger_count': 37.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 11},
#  '34': {'taxi_zone': 1,
#   'datetime': 1641124800000,
#   'passenger_count': 37.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 12},
#  '35': {'taxi_zone': 1,
#   'datetime': 1641128400000,
#   'passenger_count': 50.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 13},
#  '36': {'taxi_zone': 1,
#   'datetime': 1641132000000,
#   'passenger_count': 73.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 14},
#  '37': {'taxi_zone': 1,
#   'datetime': 1641135600000,
#   'passenger_count': 71.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 15},
#  '38': {'taxi_zone': 1,
#   'datetime': 1641139200000,
#   'passenger_count': 71.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 16},
#  '39': {'taxi_zone': 1,
#   'datetime': 1641142800000,
#   'passenger_count': 81.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 17},
#  '40': {'taxi_zone': 1,
#   'datetime': 1641146400000,
#   'passenger_count': 49.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 18},
#  '41': {'taxi_zone': 1,
#   'datetime': 1641150000000,
#   'passenger_count': 24.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 19},
#  '42': {'taxi_zone': 1,
#   'datetime': 1641153600000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 20},
#  '43': {'taxi_zone': 1,
#   'datetime': 1641157200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 21},
#  '44': {'taxi_zone': 1,
#   'datetime': 1641168000000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 0},
#  '45': {'taxi_zone': 1,
#   'datetime': 1641178800000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 3},
#  '46': {'taxi_zone': 1,
#   'datetime': 1641182400000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 4},
#  '47': {'taxi_zone': 1,
#   'datetime': 1641186000000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 5},
#  '48': {'taxi_zone': 1,
#   'datetime': 1641189600000,
#   'passenger_count': 23.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 6},
#  '49': {'taxi_zone': 1,
#   'datetime': 1641193200000,
#   'passenger_count': 17.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 7},
#  '50': {'taxi_zone': 1,
#   'datetime': 1641196800000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 8},
#  '51': {'taxi_zone': 1,
#   'datetime': 1641200400000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 9},
#  '52': {'taxi_zone': 1,
#   'datetime': 1641204000000,
#   'passenger_count': 20.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 10},
#  '53': {'taxi_zone': 1,
#   'datetime': 1641207600000,
#   'passenger_count': 17.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 11},
#  '54': {'taxi_zone': 1,
#   'datetime': 1641211200000,
#   'passenger_count': 35.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 12},
#  '55': {'taxi_zone': 1,
#   'datetime': 1641214800000,
#   'passenger_count': 40.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 13},
#  '56': {'taxi_zone': 1,
#   'datetime': 1641218400000,
#   'passenger_count': 81.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 14},
#  '57': {'taxi_zone': 1,
#   'datetime': 1641222000000,
#   'passenger_count': 62.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 15},
#  '58': {'taxi_zone': 1,
#   'datetime': 1641225600000,
#   'passenger_count': 46.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 16},
#  '59': {'taxi_zone': 1,
#   'datetime': 1641229200000,
#   'passenger_count': 31.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 17},
#  '60': {'taxi_zone': 1,
#   'datetime': 1641232800000,
#   'passenger_count': 32.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 18},
#  '61': {'taxi_zone': 1,
#   'datetime': 1641236400000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 19},
#  '62': {'taxi_zone': 1,
#   'datetime': 1641240000000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 20},
#  '63': {'taxi_zone': 1,
#   'datetime': 1641243600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 21},
#  '64': {'taxi_zone': 1,
#   'datetime': 1641247200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 22},
#  '65': {'taxi_zone': 1,
#   'datetime': 1641250800000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 23},
#  '66': {'taxi_zone': 1,
#   'datetime': 1641254400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 0},
#  '67': {'taxi_zone': 1,
#   'datetime': 1641265200000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 3},
#  '68': {'taxi_zone': 1,
#   'datetime': 1641268800000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 4},
#  '69': {'taxi_zone': 1,
#   'datetime': 1641272400000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 5},
#  '70': {'taxi_zone': 1,
#   'datetime': 1641276000000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 6},
#  '71': {'taxi_zone': 1,
#   'datetime': 1641279600000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 7},
#  '72': {'taxi_zone': 1,
#   'datetime': 1641283200000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 8},
#  '73': {'taxi_zone': 1,
#   'datetime': 1641286800000,
#   'passenger_count': 20.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 9},
#  '74': {'taxi_zone': 1,
#   'datetime': 1641290400000,
#   'passenger_count': 27.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 10},
#  '75': {'taxi_zone': 1,
#   'datetime': 1641294000000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 11},
#  '76': {'taxi_zone': 1,
#   'datetime': 1641297600000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 12},
#  '77': {'taxi_zone': 1,
#   'datetime': 1641301200000,
#   'passenger_count': 39.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 13},
#  '78': {'taxi_zone': 1,
#   'datetime': 1641304800000,
#   'passenger_count': 45.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 14},
#  '79': {'taxi_zone': 1,
#   'datetime': 1641308400000,
#   'passenger_count': 44.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 15},
#  '80': {'taxi_zone': 1,
#   'datetime': 1641312000000,
#   'passenger_count': 32.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 16},
#  '81': {'taxi_zone': 1,
#   'datetime': 1641315600000,
#   'passenger_count': 16.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 17},
#  '82': {'taxi_zone': 1,
#   'datetime': 1641319200000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 18},
#  '83': {'taxi_zone': 1,
#   'datetime': 1641322800000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 19},
#  '84': {'taxi_zone': 1,
#   'datetime': 1641326400000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 20},
#  '85': {'taxi_zone': 1,
#   'datetime': 1641333600000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 22},
#  '86': {'taxi_zone': 1,
#   'datetime': 1641337200000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 23},
#  '87': {'taxi_zone': 1,
#   'datetime': 1641340800000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 0},
#  '88': {'taxi_zone': 1,
#   'datetime': 1641355200000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 4},
#  '89': {'taxi_zone': 1,
#   'datetime': 1641358800000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 5},
#  '90': {'taxi_zone': 1,
#   'datetime': 1641362400000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 6},
#  '91': {'taxi_zone': 1,
#   'datetime': 1641366000000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 7},
#  '92': {'taxi_zone': 1,
#   'datetime': 1641369600000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 8},
#  '93': {'taxi_zone': 1,
#   'datetime': 1641373200000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 9},
#  '94': {'taxi_zone': 1,
#   'datetime': 1641376800000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 10},
#  '95': {'taxi_zone': 1,
#   'datetime': 1641380400000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 11},
#  '96': {'taxi_zone': 1,
#   'datetime': 1641384000000,
#   'passenger_count': 23.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 12},
#  '97': {'taxi_zone': 1,
#   'datetime': 1641387600000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 13},
#  '98': {'taxi_zone': 1,
#   'datetime': 1641391200000,
#   'passenger_count': 34.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 14},
#  '99': {'taxi_zone': 1,
#   'datetime': 1641394800000,
#   'passenger_count': 26.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 15},
#  '100': {'taxi_zone': 1,
#   'datetime': 1641398400000,
#   'passenger_count': 45.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 16},
#  '101': {'taxi_zone': 1,
#   'datetime': 1641402000000,
#   'passenger_count': 23.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 17},
#  '102': {'taxi_zone': 1,
#   'datetime': 1641405600000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 18},
#  '103': {'taxi_zone': 1,
#   'datetime': 1641409200000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 19},
#  '104': {'taxi_zone': 1,
#   'datetime': 1641412800000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 20},
#  '105': {'taxi_zone': 1,
#   'datetime': 1641416400000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 21},
#  '106': {'taxi_zone': 1,
#   'datetime': 1641423600000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 23},
#  '107': {'taxi_zone': 1,
#   'datetime': 1641427200000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 0},
#  '108': {'taxi_zone': 1,
#   'datetime': 1641438000000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 3},
#  '109': {'taxi_zone': 1,
#   'datetime': 1641441600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 4},
#  '110': {'taxi_zone': 1,
#   'datetime': 1641445200000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 5},
#  '111': {'taxi_zone': 1,
#   'datetime': 1641448800000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 6},
#  '112': {'taxi_zone': 1,
#   'datetime': 1641452400000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 7},
#  '113': {'taxi_zone': 1,
#   'datetime': 1641456000000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 8},
#  '114': {'taxi_zone': 1,
#   'datetime': 1641459600000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 9},
#  '115': {'taxi_zone': 1,
#   'datetime': 1641463200000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 10},
#  '116': {'taxi_zone': 1,
#   'datetime': 1641466800000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 11},
#  '117': {'taxi_zone': 1,
#   'datetime': 1641470400000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 12},
#  '118': {'taxi_zone': 1,
#   'datetime': 1641474000000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 13},
#  '119': {'taxi_zone': 1,
#   'datetime': 1641477600000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 14},
#  '120': {'taxi_zone': 1,
#   'datetime': 1641481200000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 15},
#  '121': {'taxi_zone': 1,
#   'datetime': 1641484800000,
#   'passenger_count': 43.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 16},
#  '122': {'taxi_zone': 1,
#   'datetime': 1641488400000,
#   'passenger_count': 19.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 17},
#  '123': {'taxi_zone': 1,
#   'datetime': 1641492000000,
#   'passenger_count': 27.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 18},
#  '124': {'taxi_zone': 1,
#   'datetime': 1641495600000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 19},
#  '125': {'taxi_zone': 1,
#   'datetime': 1641499200000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 20},
#  '126': {'taxi_zone': 1,
#   'datetime': 1641502800000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 21},
#  '127': {'taxi_zone': 1,
#   'datetime': 1641506400000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 22},
#  '128': {'taxi_zone': 1,
#   'datetime': 1641513600000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 0},
#  '129': {'taxi_zone': 1,
#   'datetime': 1641524400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 3},
#  '130': {'taxi_zone': 1,
#   'datetime': 1641528000000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 4},
#  '131': {'taxi_zone': 1,
#   'datetime': 1641531600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 5},
#  '132': {'taxi_zone': 1,
#   'datetime': 1641535200000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 6},
#  '133': {'taxi_zone': 1,
#   'datetime': 1641538800000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 7},
#  '134': {'taxi_zone': 1,
#   'datetime': 1641542400000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 8},
#  '135': {'taxi_zone': 1,
#   'datetime': 1641546000000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 9},
#  '136': {'taxi_zone': 1,
#   'datetime': 1641549600000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 10},
#  '137': {'taxi_zone': 1,
#   'datetime': 1641553200000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 11},
#  '138': {'taxi_zone': 1,
#   'datetime': 1641556800000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 12},
#  '139': {'taxi_zone': 1,
#   'datetime': 1641560400000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 13},
#  '140': {'taxi_zone': 1,
#   'datetime': 1641564000000,
#   'passenger_count': 59.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 14},
#  '141': {'taxi_zone': 1,
#   'datetime': 1641567600000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 15},
#  '142': {'taxi_zone': 1,
#   'datetime': 1641571200000,
#   'passenger_count': 44.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 16},
#  '143': {'taxi_zone': 1,
#   'datetime': 1641574800000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 17},
#  '144': {'taxi_zone': 1,
#   'datetime': 1641578400000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 18},
#  '145': {'taxi_zone': 1,
#   'datetime': 1641582000000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 19},
#  '146': {'taxi_zone': 1,
#   'datetime': 1641585600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 20},
#  '147': {'taxi_zone': 1,
#   'datetime': 1641589200000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 21},
#  '148': {'taxi_zone': 1,
#   'datetime': 1641596400000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 23},
#  '149': {'taxi_zone': 1,
#   'datetime': 1641603600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 1},
#  '150': {'taxi_zone': 1,
#   'datetime': 1641607200000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 2},
#  '151': {'taxi_zone': 1,
#   'datetime': 1641610800000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 3},
#  '152': {'taxi_zone': 1,
#   'datetime': 1641618000000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 5},
#  '153': {'taxi_zone': 1,
#   'datetime': 1641621600000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 6},
#  '154': {'taxi_zone': 1,
#   'datetime': 1641625200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 7},
#  '155': {'taxi_zone': 1,
#   'datetime': 1641628800000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 8},
#  '156': {'taxi_zone': 1,
#   'datetime': 1641632400000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 9},
#  '157': {'taxi_zone': 1,
#   'datetime': 1641636000000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 10},
#  '158': {'taxi_zone': 1,
#   'datetime': 1641639600000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 11},
#  '159': {'taxi_zone': 1,
#   'datetime': 1641643200000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 12},
#  '160': {'taxi_zone': 1,
#   'datetime': 1641646800000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 13},
#  '161': {'taxi_zone': 1,
#   'datetime': 1641650400000,
#   'passenger_count': 28.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 14},
#  '162': {'taxi_zone': 1,
#   'datetime': 1641654000000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 15},
#  '163': {'taxi_zone': 1,
#   'datetime': 1641657600000,
#   'passenger_count': 28.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 16},
#  '164': {'taxi_zone': 1,
#   'datetime': 1641661200000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 17},
#  '165': {'taxi_zone': 1,
#   'datetime': 1641664800000,
#   'passenger_count': 26.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 18},
#  '166': {'taxi_zone': 1,
#   'datetime': 1641668400000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 19},
#  '167': {'taxi_zone': 1,
#   'datetime': 1641672000000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 20},
#  '168': {'taxi_zone': 1,
#   'datetime': 1641675600000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 21},
#  '169': {'taxi_zone': 1,
#   'datetime': 1641693600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 2},
#  '170': {'taxi_zone': 1,
#   'datetime': 1641697200000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 3},
#  '171': {'taxi_zone': 1,
#   'datetime': 1641700800000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 4},
#  '172': {'taxi_zone': 1,
#   'datetime': 1641704400000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 5},
#  '173': {'taxi_zone': 1,
#   'datetime': 1641708000000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 6},
#  '174': {'taxi_zone': 1,
#   'datetime': 1641711600000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 7},
#  '175': {'taxi_zone': 1,
#   'datetime': 1641715200000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 8},
#  '176': {'taxi_zone': 1,
#   'datetime': 1641718800000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 9},
#  '177': {'taxi_zone': 1,
#   'datetime': 1641722400000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 10},
#  '178': {'taxi_zone': 1,
#   'datetime': 1641726000000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 11},
#  '179': {'taxi_zone': 1,
#   'datetime': 1641729600000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 12},
#  '180': {'taxi_zone': 1,
#   'datetime': 1641733200000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 13},
#  '181': {'taxi_zone': 1,
#   'datetime': 1641736800000,
#   'passenger_count': 46.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 14},
#  '182': {'taxi_zone': 1,
#   'datetime': 1641740400000,
#   'passenger_count': 26.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 15},
#  '183': {'taxi_zone': 1,
#   'datetime': 1641744000000,
#   'passenger_count': 31.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 16},
#  '184': {'taxi_zone': 1,
#   'datetime': 1641747600000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 17},
#  '185': {'taxi_zone': 1,
#   'datetime': 1641751200000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 18},
#  '186': {'taxi_zone': 1,
#   'datetime': 1641754800000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 19},
#  '187': {'taxi_zone': 1,
#   'datetime': 1641758400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 20},
#  '188': {'taxi_zone': 1,
#   'datetime': 1641762000000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 21},
#  '189': {'taxi_zone': 1,
#   'datetime': 1641772800000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 0},
#  '190': {'taxi_zone': 1,
#   'datetime': 1641780000000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 2},
#  '191': {'taxi_zone': 1,
#   'datetime': 1641783600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 3},
#  '192': {'taxi_zone': 1,
#   'datetime': 1641787200000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 4},
#  '193': {'taxi_zone': 1,
#   'datetime': 1641790800000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 5},
#  '194': {'taxi_zone': 1,
#   'datetime': 1641794400000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 6},
#  '195': {'taxi_zone': 1,
#   'datetime': 1641798000000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 7},
#  '196': {'taxi_zone': 1,
#   'datetime': 1641801600000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 8},
#  '197': {'taxi_zone': 1,
#   'datetime': 1641805200000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 9},
#  '198': {'taxi_zone': 1,
#   'datetime': 1641808800000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 10},
#  '199': {'taxi_zone': 1,
#   'datetime': 1641812400000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 11},
#  '200': {'taxi_zone': 1,
#   'datetime': 1641816000000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 12},
#  '201': {'taxi_zone': 1,
#   'datetime': 1641819600000,
#   'passenger_count': 26.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 13},
#  '202': {'taxi_zone': 1,
#   'datetime': 1641823200000,
#   'passenger_count': 19.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 14},
#  '203': {'taxi_zone': 1,
#   'datetime': 1641826800000,
#   'passenger_count': 24.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 15},
#  '204': {'taxi_zone': 1,
#   'datetime': 1641830400000,
#   'passenger_count': 23.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 16},
#  '205': {'taxi_zone': 1,
#   'datetime': 1641834000000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 17},
#  '206': {'taxi_zone': 1,
#   'datetime': 1641837600000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 18},
#  '207': {'taxi_zone': 1,
#   'datetime': 1641841200000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 19},
#  '208': {'taxi_zone': 1,
#   'datetime': 1641844800000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 20},
#  '209': {'taxi_zone': 1,
#   'datetime': 1641848400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 21},
#  '210': {'taxi_zone': 1,
#   'datetime': 1641873600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 4},
#  '211': {'taxi_zone': 1,
#   'datetime': 1641880800000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 6},
#  '212': {'taxi_zone': 1,
#   'datetime': 1641888000000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 8},
#  '213': {'taxi_zone': 1,
#   'datetime': 1641891600000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 9},
#  '214': {'taxi_zone': 1,
#   'datetime': 1641895200000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 10},
#  '215': {'taxi_zone': 1,
#   'datetime': 1641898800000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 11},
#  '216': {'taxi_zone': 1,
#   'datetime': 1641902400000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 12},
#  '217': {'taxi_zone': 1,
#   'datetime': 1641906000000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 13},
#  '218': {'taxi_zone': 1,
#   'datetime': 1641909600000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 14},
#  '219': {'taxi_zone': 1,
#   'datetime': 1641913200000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 15},
#  '220': {'taxi_zone': 1,
#   'datetime': 1641916800000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 16},
#  '221': {'taxi_zone': 1,
#   'datetime': 1641920400000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 17},
#  '222': {'taxi_zone': 1,
#   'datetime': 1641924000000,
#   'passenger_count': 20.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 18},
#  '223': {'taxi_zone': 1,
#   'datetime': 1641927600000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 19},
#  '224': {'taxi_zone': 1,
#   'datetime': 1641931200000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 20},
#  '225': {'taxi_zone': 1,
#   'datetime': 1641938400000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 22},
#  '226': {'taxi_zone': 1,
#   'datetime': 1641960000000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 4},
#  '227': {'taxi_zone': 1,
#   'datetime': 1641963600000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 5},
#  '228': {'taxi_zone': 1,
#   'datetime': 1641967200000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 6},
#  '229': {'taxi_zone': 1,
#   'datetime': 1641970800000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 7},
#  '230': {'taxi_zone': 1,
#   'datetime': 1641974400000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 8},
#  '231': {'taxi_zone': 1,
#   'datetime': 1641978000000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 9},
#  '232': {'taxi_zone': 1,
#   'datetime': 1641981600000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 10},
#  '233': {'taxi_zone': 1,
#   'datetime': 1641985200000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 11},
#  '234': {'taxi_zone': 1,
#   'datetime': 1641988800000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 12},
#  '235': {'taxi_zone': 1,
#   'datetime': 1641992400000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 13},
#  '236': {'taxi_zone': 1,
#   'datetime': 1641996000000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 14},
#  '237': {'taxi_zone': 1,
#   'datetime': 1641999600000,
#   'passenger_count': 23.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 15},
#  '238': {'taxi_zone': 1,
#   'datetime': 1642003200000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 16},
#  '239': {'taxi_zone': 1,
#   'datetime': 1642006800000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 17},
#  '240': {'taxi_zone': 1,
#   'datetime': 1642010400000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 18},
#  '241': {'taxi_zone': 1,
#   'datetime': 1642014000000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 19},
#  '242': {'taxi_zone': 1,
#   'datetime': 1642017600000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 20},
#  '243': {'taxi_zone': 1,
#   'datetime': 1642021200000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 2,
#   'hour': 21},
#  '244': {'taxi_zone': 1,
#   'datetime': 1642046400000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 4},
#  '245': {'taxi_zone': 1,
#   'datetime': 1642050000000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 5},
#  '246': {'taxi_zone': 1,
#   'datetime': 1642053600000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 6},
#  '247': {'taxi_zone': 1,
#   'datetime': 1642057200000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 7},
#  '248': {'taxi_zone': 1,
#   'datetime': 1642060800000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 8},
#  '249': {'taxi_zone': 1,
#   'datetime': 1642064400000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 9},
#  '250': {'taxi_zone': 1,
#   'datetime': 1642068000000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 10},
#  '251': {'taxi_zone': 1,
#   'datetime': 1642071600000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 11},
#  '252': {'taxi_zone': 1,
#   'datetime': 1642075200000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 12},
#  '253': {'taxi_zone': 1,
#   'datetime': 1642078800000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 13},
#  '254': {'taxi_zone': 1,
#   'datetime': 1642082400000,
#   'passenger_count': 20.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 14},
#  '255': {'taxi_zone': 1,
#   'datetime': 1642086000000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 15},
#  '256': {'taxi_zone': 1,
#   'datetime': 1642089600000,
#   'passenger_count': 16.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 16},
#  '257': {'taxi_zone': 1,
#   'datetime': 1642093200000,
#   'passenger_count': 19.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 17},
#  '258': {'taxi_zone': 1,
#   'datetime': 1642096800000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 18},
#  '259': {'taxi_zone': 1,
#   'datetime': 1642100400000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 19},
#  '260': {'taxi_zone': 1,
#   'datetime': 1642104000000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 20},
#  '261': {'taxi_zone': 1,
#   'datetime': 1642107600000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 21},
#  '262': {'taxi_zone': 1,
#   'datetime': 1642111200000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 22},
#  '263': {'taxi_zone': 1,
#   'datetime': 1642114800000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 3,
#   'hour': 23},
#  '264': {'taxi_zone': 1,
#   'datetime': 1642132800000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 4},
#  '265': {'taxi_zone': 1,
#   'datetime': 1642136400000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 5},
#  '266': {'taxi_zone': 1,
#   'datetime': 1642140000000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 6},
#  '267': {'taxi_zone': 1,
#   'datetime': 1642143600000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 7},
#  '268': {'taxi_zone': 1,
#   'datetime': 1642147200000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 8},
#  '269': {'taxi_zone': 1,
#   'datetime': 1642150800000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 9},
#  '270': {'taxi_zone': 1,
#   'datetime': 1642154400000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 10},
#  '271': {'taxi_zone': 1,
#   'datetime': 1642158000000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 11},
#  '272': {'taxi_zone': 1,
#   'datetime': 1642161600000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 12},
#  '273': {'taxi_zone': 1,
#   'datetime': 1642165200000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 13},
#  '274': {'taxi_zone': 1,
#   'datetime': 1642168800000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 14},
#  '275': {'taxi_zone': 1,
#   'datetime': 1642172400000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 15},
#  '276': {'taxi_zone': 1,
#   'datetime': 1642176000000,
#   'passenger_count': 27.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 16},
#  '277': {'taxi_zone': 1,
#   'datetime': 1642179600000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 17},
#  '278': {'taxi_zone': 1,
#   'datetime': 1642183200000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 18},
#  '279': {'taxi_zone': 1,
#   'datetime': 1642186800000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 19},
#  '280': {'taxi_zone': 1,
#   'datetime': 1642190400000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 20},
#  '281': {'taxi_zone': 1,
#   'datetime': 1642194000000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 21},
#  '282': {'taxi_zone': 1,
#   'datetime': 1642197600000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 4,
#   'hour': 22},
#  '283': {'taxi_zone': 1,
#   'datetime': 1642215600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 3},
#  '284': {'taxi_zone': 1,
#   'datetime': 1642219200000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 4},
#  '285': {'taxi_zone': 1,
#   'datetime': 1642222800000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 5},
#  '286': {'taxi_zone': 1,
#   'datetime': 1642226400000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 6},
#  '287': {'taxi_zone': 1,
#   'datetime': 1642230000000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 7},
#  '288': {'taxi_zone': 1,
#   'datetime': 1642233600000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 8},
#  '289': {'taxi_zone': 1,
#   'datetime': 1642237200000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 9},
#  '290': {'taxi_zone': 1,
#   'datetime': 1642240800000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 10},
#  '291': {'taxi_zone': 1,
#   'datetime': 1642244400000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 11},
#  '292': {'taxi_zone': 1,
#   'datetime': 1642248000000,
#   'passenger_count': 19.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 12},
#  '293': {'taxi_zone': 1,
#   'datetime': 1642251600000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 13},
#  '294': {'taxi_zone': 1,
#   'datetime': 1642255200000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 14},
#  '295': {'taxi_zone': 1,
#   'datetime': 1642258800000,
#   'passenger_count': 25.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 15},
#  '296': {'taxi_zone': 1,
#   'datetime': 1642262400000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 16},
#  '297': {'taxi_zone': 1,
#   'datetime': 1642266000000,
#   'passenger_count': 19.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 17},
#  '298': {'taxi_zone': 1,
#   'datetime': 1642269600000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 18},
#  '299': {'taxi_zone': 1,
#   'datetime': 1642273200000,
#   'passenger_count': 9.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 19},
#  '300': {'taxi_zone': 1,
#   'datetime': 1642276800000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 20},
#  '301': {'taxi_zone': 1,
#   'datetime': 1642280400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 5,
#   'hour': 21},
#  '302': {'taxi_zone': 1,
#   'datetime': 1642302000000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 3},
#  '303': {'taxi_zone': 1,
#   'datetime': 1642305600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 4},
#  '304': {'taxi_zone': 1,
#   'datetime': 1642309200000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 5},
#  '305': {'taxi_zone': 1,
#   'datetime': 1642312800000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 6},
#  '306': {'taxi_zone': 1,
#   'datetime': 1642316400000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 7},
#  '307': {'taxi_zone': 1,
#   'datetime': 1642320000000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 8},
#  '308': {'taxi_zone': 1,
#   'datetime': 1642323600000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 9},
#  '309': {'taxi_zone': 1,
#   'datetime': 1642327200000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 10},
#  '310': {'taxi_zone': 1,
#   'datetime': 1642330800000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 11},
#  '311': {'taxi_zone': 1,
#   'datetime': 1642334400000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 12},
#  '312': {'taxi_zone': 1,
#   'datetime': 1642338000000,
#   'passenger_count': 13.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 13},
#  '313': {'taxi_zone': 1,
#   'datetime': 1642341600000,
#   'passenger_count': 28.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 14},
#  '314': {'taxi_zone': 1,
#   'datetime': 1642345200000,
#   'passenger_count': 20.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 15},
#  '315': {'taxi_zone': 1,
#   'datetime': 1642348800000,
#   'passenger_count': 21.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 16},
#  '316': {'taxi_zone': 1,
#   'datetime': 1642352400000,
#   'passenger_count': 8.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 17},
#  '317': {'taxi_zone': 1,
#   'datetime': 1642356000000,
#   'passenger_count': 10.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 18},
#  '318': {'taxi_zone': 1,
#   'datetime': 1642359600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 19},
#  '319': {'taxi_zone': 1,
#   'datetime': 1642363200000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 20},
#  '320': {'taxi_zone': 1,
#   'datetime': 1642366800000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 6,
#   'hour': 21},
#  '321': {'taxi_zone': 1,
#   'datetime': 1642377600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 0},
#  '322': {'taxi_zone': 1,
#   'datetime': 1642395600000,
#   'passenger_count': 15.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 5},
#  '323': {'taxi_zone': 1,
#   'datetime': 1642399200000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 6},
#  '324': {'taxi_zone': 1,
#   'datetime': 1642402800000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 7},
#  '325': {'taxi_zone': 1,
#   'datetime': 1642406400000,
#   'passenger_count': 3.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 8},
#  '326': {'taxi_zone': 1,
#   'datetime': 1642410000000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 9},
#  '327': {'taxi_zone': 1,
#   'datetime': 1642413600000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 10},
#  '328': {'taxi_zone': 1,
#   'datetime': 1642417200000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 11},
#  '329': {'taxi_zone': 1,
#   'datetime': 1642420800000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 12},
#  '330': {'taxi_zone': 1,
#   'datetime': 1642424400000,
#   'passenger_count': 12.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 13},
#  '331': {'taxi_zone': 1,
#   'datetime': 1642428000000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 14},
#  '332': {'taxi_zone': 1,
#   'datetime': 1642431600000,
#   'passenger_count': 32.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 15},
#  '333': {'taxi_zone': 1,
#   'datetime': 1642435200000,
#   'passenger_count': 22.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 16},
#  '334': {'taxi_zone': 1,
#   'datetime': 1642438800000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 17},
#  '335': {'taxi_zone': 1,
#   'datetime': 1642442400000,
#   'passenger_count': 29.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 18},
#  '336': {'taxi_zone': 1,
#   'datetime': 1642446000000,
#   'passenger_count': 6.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 19},
#  '337': {'taxi_zone': 1,
#   'datetime': 1642449600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 0,
#   'hour': 20},
#  '338': {'taxi_zone': 1,
#   'datetime': 1642478400000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 4},
#  '339': {'taxi_zone': 1,
#   'datetime': 1642482000000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 5},
#  '340': {'taxi_zone': 1,
#   'datetime': 1642485600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 6},
#  '341': {'taxi_zone': 1,
#   'datetime': 1642489200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 7},
#  '342': {'taxi_zone': 1,
#   'datetime': 1642492800000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 8},
#  '343': {'taxi_zone': 1,
#   'datetime': 1642496400000,
#   'passenger_count': 14.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 9},
#  '344': {'taxi_zone': 1,
#   'datetime': 1642500000000,
#   'passenger_count': 18.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 10},
#  '345': {'taxi_zone': 1,
#   'datetime': 1642503600000,
#   'passenger_count': 5.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 11},
#  '346': {'taxi_zone': 1,
#   'datetime': 1642507200000,
#   'passenger_count': 7.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 12},
#  '347': {'taxi_zone': 1,
#   'datetime': 1642510800000,
#   'passenger_count': 25.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 13},
#  '348': {'taxi_zone': 1,
#   'datetime': 1642514400000,
#   'passenger_count': 24.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 14},
#  '349': {'taxi_zone': 1,
#   'datetime': 1642518000000,
#   'passenger_count': 24.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 15},
#  '350': {'taxi_zone': 1,
#   'datetime': 1642521600000,
#   'passenger_count': 32.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 16},
#  '351': {'taxi_zone': 1,
#   'datetime': 1642525200000,
#   'passenger_count': 19.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 17},
#  '352': {'taxi_zone': 1,
#   'datetime': 1642528800000,
#   'passenger_count': 11.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 18},
#  '353': {'taxi_zone': 1,
#   'datetime': 1642532400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 19},
#  '354': {'taxi_zone': 1,
#   'datetime': 1642536000000,
#   'passenger_count': 4.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 20},
#  '355': {'taxi_zone': 1,
#   'datetime': 1642539600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-01',
#   'week': 1,
#   'hour': 21},
# ...
#   'hour': 5},
#  '882': {'taxi_zone': 1,
#   'datetime': 1645077600000,
#   'passenger_count': 13.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 6},
#  '883': {'taxi_zone': 1,
#   'datetime': 1645081200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 7},
#  '884': {'taxi_zone': 1,
#   'datetime': 1645084800000,
#   'passenger_count': 33.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 8},
#  '885': {'taxi_zone': 1,
#   'datetime': 1645088400000,
#   'passenger_count': 7.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 9},
#  '886': {'taxi_zone': 1,
#   'datetime': 1645092000000,
#   'passenger_count': 5.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 10},
#  '887': {'taxi_zone': 1,
#   'datetime': 1645095600000,
#   'passenger_count': 9.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 11},
#  '888': {'taxi_zone': 1,
#   'datetime': 1645099200000,
#   'passenger_count': 27.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 12},
#  '889': {'taxi_zone': 1,
#   'datetime': 1645102800000,
#   'passenger_count': 20.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 13},
#  '890': {'taxi_zone': 1,
#   'datetime': 1645106400000,
#   'passenger_count': 32.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 14},
#  '891': {'taxi_zone': 1,
#   'datetime': 1645110000000,
#   'passenger_count': 24.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 15},
#  '892': {'taxi_zone': 1,
#   'datetime': 1645113600000,
#   'passenger_count': 21.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 16},
#  '893': {'taxi_zone': 1,
#   'datetime': 1645117200000,
#   'passenger_count': 32.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 17},
#  '894': {'taxi_zone': 1,
#   'datetime': 1645120800000,
#   'passenger_count': 43.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 18},
#  '895': {'taxi_zone': 1,
#   'datetime': 1645124400000,
#   'passenger_count': 30.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 19},
#  '896': {'taxi_zone': 1,
#   'datetime': 1645128000000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 20},
#  '897': {'taxi_zone': 1,
#   'datetime': 1645131600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 21},
#  '898': {'taxi_zone': 1,
#   'datetime': 1645135200000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 22},
#  '899': {'taxi_zone': 1,
#   'datetime': 1645138800000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 3,
#   'hour': 23},
#  '900': {'taxi_zone': 1,
#   'datetime': 1645153200000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 3},
#  '901': {'taxi_zone': 1,
#   'datetime': 1645156800000,
#   'passenger_count': 11.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 4},
#  '902': {'taxi_zone': 1,
#   'datetime': 1645160400000,
#   'passenger_count': 24.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 5},
#  '903': {'taxi_zone': 1,
#   'datetime': 1645164000000,
#   'passenger_count': 27.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 6},
#  '904': {'taxi_zone': 1,
#   'datetime': 1645167600000,
#   'passenger_count': 19.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 7},
#  '905': {'taxi_zone': 1,
#   'datetime': 1645171200000,
#   'passenger_count': 21.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 8},
#  '906': {'taxi_zone': 1,
#   'datetime': 1645174800000,
#   'passenger_count': 24.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 9},
#  '907': {'taxi_zone': 1,
#   'datetime': 1645178400000,
#   'passenger_count': 20.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 10},
#  '908': {'taxi_zone': 1,
#   'datetime': 1645182000000,
#   'passenger_count': 8.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 11},
#  '909': {'taxi_zone': 1,
#   'datetime': 1645185600000,
#   'passenger_count': 14.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 12},
#  '910': {'taxi_zone': 1,
#   'datetime': 1645189200000,
#   'passenger_count': 38.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 13},
#  '911': {'taxi_zone': 1,
#   'datetime': 1645192800000,
#   'passenger_count': 40.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 14},
#  '912': {'taxi_zone': 1,
#   'datetime': 1645196400000,
#   'passenger_count': 48.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 15},
#  '913': {'taxi_zone': 1,
#   'datetime': 1645200000000,
#   'passenger_count': 64.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 16},
#  '914': {'taxi_zone': 1,
#   'datetime': 1645203600000,
#   'passenger_count': 42.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 17},
#  '915': {'taxi_zone': 1,
#   'datetime': 1645207200000,
#   'passenger_count': 42.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 18},
#  '916': {'taxi_zone': 1,
#   'datetime': 1645210800000,
#   'passenger_count': 17.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 19},
#  '917': {'taxi_zone': 1,
#   'datetime': 1645214400000,
#   'passenger_count': 14.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 20},
#  '918': {'taxi_zone': 1,
#   'datetime': 1645218000000,
#   'passenger_count': 6.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 21},
#  '919': {'taxi_zone': 1,
#   'datetime': 1645221600000,
#   'passenger_count': 8.0,
#   'year_month': '2022-02',
#   'week': 4,
#   'hour': 22},
#  '920': {'taxi_zone': 1,
#   'datetime': 1645239600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 3},
#  '921': {'taxi_zone': 1,
#   'datetime': 1645243200000,
#   'passenger_count': 10.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 4},
#  '922': {'taxi_zone': 1,
#   'datetime': 1645246800000,
#   'passenger_count': 19.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 5},
#  '923': {'taxi_zone': 1,
#   'datetime': 1645250400000,
#   'passenger_count': 26.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 6},
#  '924': {'taxi_zone': 1,
#   'datetime': 1645254000000,
#   'passenger_count': 23.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 7},
#  '925': {'taxi_zone': 1,
#   'datetime': 1645257600000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 8},
#  '926': {'taxi_zone': 1,
#   'datetime': 1645261200000,
#   'passenger_count': 14.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 9},
#  '927': {'taxi_zone': 1,
#   'datetime': 1645264800000,
#   'passenger_count': 16.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 10},
#  '928': {'taxi_zone': 1,
#   'datetime': 1645268400000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 11},
#  '929': {'taxi_zone': 1,
#   'datetime': 1645272000000,
#   'passenger_count': 17.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 12},
#  '930': {'taxi_zone': 1,
#   'datetime': 1645275600000,
#   'passenger_count': 27.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 13},
#  '931': {'taxi_zone': 1,
#   'datetime': 1645279200000,
#   'passenger_count': 40.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 14},
#  '932': {'taxi_zone': 1,
#   'datetime': 1645282800000,
#   'passenger_count': 49.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 15},
#  '933': {'taxi_zone': 1,
#   'datetime': 1645286400000,
#   'passenger_count': 46.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 16},
#  '934': {'taxi_zone': 1,
#   'datetime': 1645290000000,
#   'passenger_count': 17.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 17},
#  '935': {'taxi_zone': 1,
#   'datetime': 1645293600000,
#   'passenger_count': 28.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 18},
#  '936': {'taxi_zone': 1,
#   'datetime': 1645297200000,
#   'passenger_count': 13.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 19},
#  '937': {'taxi_zone': 1,
#   'datetime': 1645300800000,
#   'passenger_count': 8.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 20},
#  '938': {'taxi_zone': 1,
#   'datetime': 1645304400000,
#   'passenger_count': 7.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 21},
#  '939': {'taxi_zone': 1,
#   'datetime': 1645308000000,
#   'passenger_count': 4.0,
#   'year_month': '2022-02',
#   'week': 5,
#   'hour': 22},
#  '940': {'taxi_zone': 1,
#   'datetime': 1645315200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 0},
#  '941': {'taxi_zone': 1,
#   'datetime': 1645318800000,
#   'passenger_count': 2.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 1},
#  '942': {'taxi_zone': 1,
#   'datetime': 1645322400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 2},
#  '943': {'taxi_zone': 1,
#   'datetime': 1645329600000,
#   'passenger_count': 5.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 4},
#  '944': {'taxi_zone': 1,
#   'datetime': 1645333200000,
#   'passenger_count': 4.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 5},
#  '945': {'taxi_zone': 1,
#   'datetime': 1645336800000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 6},
#  '946': {'taxi_zone': 1,
#   'datetime': 1645340400000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 7},
#  '947': {'taxi_zone': 1,
#   'datetime': 1645344000000,
#   'passenger_count': 19.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 8},
#  '948': {'taxi_zone': 1,
#   'datetime': 1645347600000,
#   'passenger_count': 29.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 9},
#  '949': {'taxi_zone': 1,
#   'datetime': 1645351200000,
#   'passenger_count': 11.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 10},
#  '950': {'taxi_zone': 1,
#   'datetime': 1645354800000,
#   'passenger_count': 13.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 11},
#  '951': {'taxi_zone': 1,
#   'datetime': 1645358400000,
#   'passenger_count': 21.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 12},
#  '952': {'taxi_zone': 1,
#   'datetime': 1645362000000,
#   'passenger_count': 42.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 13},
#  '953': {'taxi_zone': 1,
#   'datetime': 1645365600000,
#   'passenger_count': 47.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 14},
#  '954': {'taxi_zone': 1,
#   'datetime': 1645369200000,
#   'passenger_count': 36.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 15},
#  '955': {'taxi_zone': 1,
#   'datetime': 1645372800000,
#   'passenger_count': 24.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 16},
#  '956': {'taxi_zone': 1,
#   'datetime': 1645376400000,
#   'passenger_count': 24.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 17},
#  '957': {'taxi_zone': 1,
#   'datetime': 1645380000000,
#   'passenger_count': 30.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 18},
#  '958': {'taxi_zone': 1,
#   'datetime': 1645383600000,
#   'passenger_count': 16.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 19},
#  '959': {'taxi_zone': 1,
#   'datetime': 1645387200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 20},
#  '960': {'taxi_zone': 1,
#   'datetime': 1645390800000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 6,
#   'hour': 21},
#  '961': {'taxi_zone': 1,
#   'datetime': 1645401600000,
#   'passenger_count': 3.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 0},
#  '962': {'taxi_zone': 1,
#   'datetime': 1645405200000,
#   'passenger_count': 4.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 1},
#  '963': {'taxi_zone': 1,
#   'datetime': 1645416000000,
#   'passenger_count': 17.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 4},
#  '964': {'taxi_zone': 1,
#   'datetime': 1645419600000,
#   'passenger_count': 10.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 5},
#  '965': {'taxi_zone': 1,
#   'datetime': 1645423200000,
#   'passenger_count': 5.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 6},
#  '966': {'taxi_zone': 1,
#   'datetime': 1645426800000,
#   'passenger_count': 14.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 7},
#  '967': {'taxi_zone': 1,
#   'datetime': 1645430400000,
#   'passenger_count': 26.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 8},
#  '968': {'taxi_zone': 1,
#   'datetime': 1645434000000,
#   'passenger_count': 27.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 9},
#  '969': {'taxi_zone': 1,
#   'datetime': 1645437600000,
#   'passenger_count': 37.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 10},
#  '970': {'taxi_zone': 1,
#   'datetime': 1645441200000,
#   'passenger_count': 20.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 11},
#  '971': {'taxi_zone': 1,
#   'datetime': 1645444800000,
#   'passenger_count': 25.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 12},
#  '972': {'taxi_zone': 1,
#   'datetime': 1645448400000,
#   'passenger_count': 61.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 13},
#  '973': {'taxi_zone': 1,
#   'datetime': 1645452000000,
#   'passenger_count': 49.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 14},
#  '974': {'taxi_zone': 1,
#   'datetime': 1645455600000,
#   'passenger_count': 45.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 15},
#  '975': {'taxi_zone': 1,
#   'datetime': 1645459200000,
#   'passenger_count': 46.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 16},
#  '976': {'taxi_zone': 1,
#   'datetime': 1645462800000,
#   'passenger_count': 79.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 17},
#  '977': {'taxi_zone': 1,
#   'datetime': 1645466400000,
#   'passenger_count': 30.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 18},
#  '978': {'taxi_zone': 1,
#   'datetime': 1645470000000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 19},
#  '979': {'taxi_zone': 1,
#   'datetime': 1645473600000,
#   'passenger_count': 2.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 20},
#  '980': {'taxi_zone': 1,
#   'datetime': 1645477200000,
#   'passenger_count': 2.0,
#   'year_month': '2022-02',
#   'week': 0,
#   'hour': 21},
#  '981': {'taxi_zone': 1,
#   'datetime': 1645498800000,
#   'passenger_count': 4.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 3},
#  '982': {'taxi_zone': 1,
#   'datetime': 1645502400000,
#   'passenger_count': 11.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 4},
#  '983': {'taxi_zone': 1,
#   'datetime': 1645506000000,
#   'passenger_count': 17.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 5},
#  '984': {'taxi_zone': 1,
#   'datetime': 1645509600000,
#   'passenger_count': 17.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 6},
#  '985': {'taxi_zone': 1,
#   'datetime': 1645513200000,
#   'passenger_count': 9.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 7},
#  '986': {'taxi_zone': 1,
#   'datetime': 1645516800000,
#   'passenger_count': 11.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 8},
#  '987': {'taxi_zone': 1,
#   'datetime': 1645520400000,
#   'passenger_count': 14.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 9},
#  '988': {'taxi_zone': 1,
#   'datetime': 1645524000000,
#   'passenger_count': 3.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 10},
#  '989': {'taxi_zone': 1,
#   'datetime': 1645527600000,
#   'passenger_count': 14.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 11},
#  '990': {'taxi_zone': 1,
#   'datetime': 1645531200000,
#   'passenger_count': 26.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 12},
#  '991': {'taxi_zone': 1,
#   'datetime': 1645534800000,
#   'passenger_count': 16.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 13},
#  '992': {'taxi_zone': 1,
#   'datetime': 1645538400000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 14},
#  '993': {'taxi_zone': 1,
#   'datetime': 1645542000000,
#   'passenger_count': 15.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 15},
#  '994': {'taxi_zone': 1,
#   'datetime': 1645545600000,
#   'passenger_count': 17.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 16},
#  '995': {'taxi_zone': 1,
#   'datetime': 1645549200000,
#   'passenger_count': 21.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 17},
#  '996': {'taxi_zone': 1,
#   'datetime': 1645552800000,
#   'passenger_count': 23.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 18},
#  '997': {'taxi_zone': 1,
#   'datetime': 1645556400000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 19},
#  '998': {'taxi_zone': 1,
#   'datetime': 1645560000000,
#   'passenger_count': 7.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 20},
#  '999': {'taxi_zone': 1,
#   'datetime': 1645563600000,
#   'passenger_count': 1.0,
#   'year_month': '2022-02',
#   'week': 1,
#   'hour': 21},
#  ...}
